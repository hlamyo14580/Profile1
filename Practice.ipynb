# %% [markdown]
# <a href="https://colab.research.google.com/github/hlamyo14580/Profile1/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# sample_data/

# %%
b =['apple','orange',100,200]

# %%
def type_checking(x):
  return isinstance(x,str)

# %%
b
# Out:
# ['apple', 'orange', 100, 200]

# %%
def type_checking(x):
  return isinstance(x,str)
  filter(type_checking,b)
  list(filter(type_checking,b))

# %%
b
# Out:
# ['apple', 'orange', 100, 200]

# %%
c=[200,300]
def mult (x):
  return x*2
list(map(mult,c))
# Out:
# [400, 600]

# %%
c
# Out:
# [200, 300]

# %%
f=[2,5,10]

# %%
def multi(x):
  return x * 2
list(map(multi,f))
# Out:
# [4, 10, 20]

# %%
def multi(x):
  return x * 5
list(map(multi,f))
# Out:
# [10, 25, 50]

# %%
g = [5,10,15]

# %%
def multi(y):
  return y * 10
list(map(multi,g))
# Out:
# [50, 100, 150]

# %%
a =["hi","hello"]

# %%
def captilize(x):
  return x.upper()
list(map(captilize,a))
# Out:
# ['HI', 'HELLO']

# %%
d=["HELLO","HI"]

# %%
def lower(z):
  return z.lower()
list(map(lower,d))
# Out:
# ['hello', 'hi']

# %%
for i in d:
  i=i.lower()
  print(i)
# Out:
# hello
# hi

# %%
d
# Out:
# ['HELLO', 'HI']

# %%
d
# Out:
# ['HELLO', 'HI']

# %%
f =["hi","hello"]

# %%
for i in f:
  i=i.upper()
  print(i)
# Out:
# HI
# HELLO

# %%
def upper(x):
  return x.upper()
list(map(upper,f))
# Out:
# ['HI', 'HELLO']

# %%
def upper(x):
  return x.upper()
list(map(upper,f))
# Out:
# ['HI', 'HELLO']

# %%
food_menu=['coffee','tea','sandwich']
order ='juice'
if order in food_menu:
  print('yes')
else:
  print('no')
# Out:
# no

# %%
order='tea'

# %%
if order == 'coffee' or order == 'tea' or order =='sandwich':
  print('yes')
else:
  print('no')
# Out:
# no

# %%
order ='sandwich'

# %%
"""thanlwin Str,
nyaunggone myothit,
data tsp,
ygn"""
# Out:
# 'thanlwin Str,\nnyaunggone myothit,\ndata tsp,\nygn'

# %%
"""thanlwin Str,\n
nyaunggone myothit,\n
data tsp,\n
ygn\n"""
# Out:
# 'thanlwin Str,\n\nnyaunggone myothit,\n\ndata tsp,\n\nygn\n'

# %%
print(hla myo\n
dala\n

ygn\n)
# Out:
#   File "<ipython-input-5-cbf0aebb7a2e>", line 1
#     print(hla myo\n
#                   ^
# SyntaxError: unexpected character after line continuation character

# %%
print('one\ntwo\nthree\n')
# Out:
# one
# two
# three

# %%
print("""hla myo
dala
ygn""")
# Out:
# hla myo
# dala
# ygn

# %%
print("""hla myo
dala
ygn""")
# Out:
# hla myo
# dala
# ygn

# %%
medicine="Paracetamol"
dosage = 5
duration = 4
instruction = " Please take {} in {}ml for every {} hours with water as per instruction .".format(medicine,dosage,duration)
print(instruction)
# Out:
#  Please take Paracetamol in 5ml for every 4 hours with water as per instruction .

# %%
medicine="Paracetamol"
dosage = 5
duration = 4
instruction_kids = " Please take {} in {} ml for every {} hours with water as per doctor's instruction .".format(medicine,dosage,duration)
print(instruction_kids)
# Out:
#  Please take Paracetamol in 5 ml for every 4 hours with water as per doctor's instruction .

# %%
instruction
# Out:
# " Please take Paracetamol in 5 ml for every 4 hours with water as per doctor's instruction ."

# %%
medicine="Paracetamol"
dosage = 7
duration = 3
Frequency = 3
instruction_Adult = " Please take {} in {} ml for every {} hours ,{} times a day with water as per doctor's instruction .".format(medicine,dosage,duration,Frequency)
print(instruction_Adult)
# Out:
#  Please take Paracetamol in 7 ml for every 3 hours ,3 times a day with water as per doctor's instruction .

# %%
instruction_kids
# Out:
# " Please take Paracetamol in 5 ml for every 4 hours with water as per doctor's instruction ."

# %%
instruction_Adult
# Out:
# " Please take Paracetamol in 7 ml for every 3 hours ,3 times a day with water as per doctor's instruction ."

# %%
follow ="{medicine} : Please take {dosage} ml in {duration} hours durations {frequency} times a day with warm water as per physician instruciton ".format(medicine = "Paracetamol" , dosage = 5 , duration = 4 , frequency = 3)
print(follow)
# Out:
# Paracetamol : Please take 5 ml in 4 hours durations 3 times a day with warm water as per physician instruciton

# %%
Doctor_word = "apply {balm} on {body} {duration} a day ".format( balm = " Tiger " , body = " legs " , duration = 3)
print(Doctor_word)
# Out:
# apply  Tiger  on  legs  3 a day

# %%
width = 5
height = 10
area = width * height
perimeter = 2 * (width + height)
print(f'The perimeter is { perimeter} and the area is {area}.')
# Out:
# The perimeter is 30 and the area is 50.

# %%
multiplication = 5 * 9
multiplication = 5 * 10
multiplication = 5 * 11
multiplication = 5 * 12
print(f'5 x 9 = {multiplication}')
print(f'5 x 10 = {multiplication}')
print(f'5 x 11 = {multiplication}')
print(f'5 x 12 = {multiplication}')
# Out:
# 5 x 8 = 45
# 5 x 9 = 45

# %%
5 * 9
# Out:
# 45

# %%
multiplication = 5 * 1
multiplication = 5 * 2
multiplication = 5 * 3
multiplication = 5 * 4
multiplication = 5 * 5
multiplication = 5 * 6
multiplication = 5 * 7
multiplication = 5 * 8
multiplication = 5 * 9
multiplication = 5 * 10
multiplication = 5 * 11
multiplication = 5 * 12
print(f'5 x 1 = {multiplication}')
print(f'5 x 2 = {multiplication}')
print(f'5 x 3 = {multiplication}')
print(f'5 x 4 = {multiplication}')
print(f'5 x 5 = {multiplication}')
print(f'5 x 6 = {multiplication}')
print(f'5 x 7 = {multiplication}')
print(f'5 x 8 = {multiplication}')
print(f'5 x 9 = {multiplication}')
print(f'5 x 10 = {multiplication}')
print(f'5 x 11 = {multiplication}')
print(f'5 x 12 = {multiplication}')
# Out:
# 5 x 1 = 60
# 5 x 2 = 60
# 5 x 3 = 60
# 5 x 4 = 60
# 5 x 5 = 60
# 5 x 6 = 60
# 5 x 7 = 60
# 5 x 8 = 60
# 5 x 9 = 60
# 5 x 10 = 60
# 5 x 11 = 60
# 5 x 12 = 60

# %%
# !pip install pandas

# %%
5 * 1
# Out:
# 5

# %%
5 *2
# Out:
# 10

# %%
6 *1
# Out:
# 6

# %%
multiplication1= 5 * 1
multiplication2 = 5 * 2
multiplication3= 5 * 3
multiplication4 = 5 * 4
multiplication5= 5 * 5
multiplication6= 5 * 6
multiplication7= 5 * 7
multiplication8= 5 * 8
multiplication9= 5 * 9
multiplication10= 5 * 10
multiplication11= 5 * 11
multiplication12= 5 * 12
print(f'5 x 1 = {multiplication1}')
print(f'5 x 2 = {multiplication2}')
print(f'5 x 3 = {multiplication3}')
print(f'5 x 4 = {multiplication4}')
print(f'5 x 5 = {multiplication5}')
print(f'5 x 6 = {multiplication6}')
print(f'5 x 7 = {multiplication7}')
print(f'5 x 8 = {multiplication8}')
print(f'5 x 9 = {multiplication9}')
print(f'5 x 10 = {multiplication10}')
print(f'5 x 11 = {multiplication11}')
print(f'5 x 12 = {multiplication12}')
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 5 x 11 = 55
# 5 x 12 = 60

# %%
multiplication1= 6 * 1
multiplication2= 6 * 2
multiplication3= 6 * 3
multiplication4= 6 * 4
multiplication5= 6 * 5
multiplication6= 6 * 6
multiplication7= 6 * 7
multiplication8= 6 * 8
multiplication9= 6 * 9
multiplication10= 6 * 10
multiplication11= 6 * 11
multiplication12= 6 * 12
print(f'6 x 1 = {multiplication1}')
print(f'6 x 2 = {multiplication2}')
print(f'6 x 3 = {multiplication3}')
print(f'6 x 4 = {multiplication4}')
print(f'6 x 5 = {multiplication5}')
print(f'6 x 6 = {multiplication6}')
print(f'6 x 7 = {multiplication7}')
print(f'6 x 8 = {multiplication8}')
print(f'6 x 9 = {multiplication9}')
print(f'6 x 10 = {multiplication10}')
print(f'6 x 11 = {multiplication11}')
print(f'6 x 12 = {multiplication12}')
# Out:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 6 x 11 = 66
# 6 x 12 = 72

# %%
message = str.capitalize(" HLA MYO ")
print(message)
# Out:
#  hla myo

# %%
message = str.capitalize("hla myo")
print(message)
# Out:
# Hla myo

# %%
"hla myo".capitalize()
# Out:
# 'Hla myo'

# %%
"hla myo".upper()
# Out:
# 'HLA MYO'

# %%
"hla myo".lower()
# Out:
# 'hla myo'

# %%
"hla myo".title()
# Out:
# 'Hla Myo'

# %%
"hla myo".swapcase()
# Out:
# 'HLA MYO'

# %%
"hla myo".casefold()
# Out:
# 'hla myo'

# %%
"hla myo".center(50)
# Out:
# '                     hla myo                      '

# %%
"hla myo".center(50,"*")
# Out:
# '*********************hla myo**********************'

# %%
name = input("Enter your name:")
print("Hello !" + name + ","+ " welcome singapore")
# Out:
# Enter your name:ko hla myo
# Hello !ko hla myo, welcome singapore

# %%
age = input ( " Enter your age :")
print("your age is " + age + " years old")
# Out:
#  Enter your age :44
# your age is 44 years old

# %%
age = input ( " Enter your age :")
print("your age is " + age + " years old")
# Out:
#  Enter your age :43
# your age is 43 years old

# %%
x = 5
y = 10
z = x + y
print(z)
# Out:
# 15

# %%
x = "4"
y = "5"
z = x + y
print(z)
# Out:
# 45

# %%
z = int(x) + int(y)
print(z)
# Out:
# 9

# %%
bill = int(input())
print(int(bill * 20 / 100))
# Out:
# 20
# 4

# %%
num = 6
if num > 7 :
  print("greater than 7")
  if num > 6:
    print("greater than 6")
if num > 5:
      print("greater than 5")
else:
  print("less than 5")
# Out:
# greater than 5

# %%
x = 528
if x == 1500:
  print("yes")
elif x <150:
  print("no")
else:
  print("may be")
# Out:
# may be

# %%
num =3
if num == 1:
  print("one")
  if num == 2:
    print("two")
if num == 3:
      print("three")
      if num == 4:
        print("four")
        if num == 5:
          print("five")
else:
  print("may be")
# Out:
# three

# %%
grade = int ( input ( " Enter your grade : "))
if grade >= 90 :
  lettergrade = "A"
elif grade >= 80:
  lettergrade = "B"
elif grade >= 70:
  lettergrade = "C"
elif grade >= 60:
  lettergrade = "D"
elif grade >= 50:
  lettergrade = "E"
elif grade >= 40:
  lettergrade = "F"
else:
  lettergrade = "Fail"
print("Your Lettergrade is " + lettergrade + " .")
# Out:
#  Enter your grade : 60
# Your Lettergrade is D .

# %%
mark = int ( input("Enter your mark :   "))
if mark < 40 :
    print("You have failed")
elif mark > 40 :
    print("You have passed.")
elif mark > 60 :
    print("You have credited.")
elif mark > 70 :
    print("You have outstanding")
elif mark > 90 :
    print("You have super - outstanding")
else:
    print("Input error")
# Out:
# Enter your mark :   90
# You have passed.

# %%
mark = int ( input("Enter your mark :   "))
if mark < 40 :
    print("You have failed")
elif mark > 40 and mark <= 65 :
    print("You have passed.")
elif mark > 65 and mark <= 80 :
    print("You have credited ")
else:
    print("Input error")
# Out:
# Enter your mark :   90
# Input error

# %%
password = ""
while password != "hlamyo":
  password = input (" Enter your password :")
print("login in valid")
# Out:
#  Enter your password :hla
#  Enter your password :myo
#  Enter your password :hlamyo
# login in valid

# %%
while password != "hm" :
  password = input (" Enter your password :")
print(" login in valid")
# Out:
#  Enter your password :h
#  Enter your password :m
#  Enter your password :mf
#  Enter your password :hm
# login in valid

# %%
while key != "hm123" :
  key ( input ( " Enter your key : "))
print("go on!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-8bb508cde2bc> in <cell line: 1>()
# ----> 1 while key != "hm123" :
#       2   key ( input ( " Enter your key : "))
#       3 print("go on!")
#
# NameError: name 'key' is not defined

# %%
key=""
while key != "hm123" :
  key ( input ( " Enter your key : "))
print("go on!")
# Out:
#  Enter your key : 123
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-28a17ccf0b25> in <cell line: 2>()
#       1 key=""
#       2 while key != "hm123" :
# ----> 3   key ( input ( " Enter your key : "))
#       4 print("go on!")
#
# TypeError: 'str' object is not callable

# %%
key=""
while key != "123" :
  key = ( input ( " Enter your key : "))
print("go on!")
# Out:
#  Enter your key : gh
#  Enter your key : dghh
#  Enter your key : 123
# go on!

# %%
i = 1
while i <= 5 :
  print(i)
  i = i + 1
print("finished !")
# Out:
# 1
# 2
# 3
# 4
# 5
# finished !

# %%
import seaborn as sb
sb.load_dataset('tips')
df = sb.load_dataset('tips')

# %%
for a in df['total_bill']:
  print(a)
# Out:
# 16.99
# 10.34
# 21.01
# 23.68
# 24.59
# 25.29
# 8.77
# 26.88
# 15.04
# 14.78
# 10.27
# 35.26
# 15.42
# 18.43
# 14.83
# 21.58
# 10.33
# 16.29
# 16.97
# 20.65
# 17.92
# 20.29
# 15.77
# 39.42
# 19.82
# 17.81
# 13.37
# 12.69
# 21.7
# 19.65
# 9.55
# 18.35
# 15.06
# 20.69
# 17.78
# 24.06
# 16.31
# 16.93
# 18.69
# 31.27
# 16.04
# 17.46
# 13.94
# 9.68
# 30.4
# 18.29
# 22.23
# 32.4
# 28.55
# 18.04
# 12.54
# 10.29
# 34.81
# 9.94
# 25.56
# 19.49
# 38.01
# 26.41
# 11.24
# 48.27
# 20.29
# 13.81
# 11.02
# 18.29
# 17.59
# 20.08
# 16.45
# 3.07
# 20.23
# 15.01
# 12.02
# 17.07
# 26.86
# 25.28
# 14.73
# 10.51
# 17.92
# 27.2
# 22.76
# 17.29
# 19.44
# 16.66
# 10.07
# 32.68
# 15.98
# 34.83
# 13.03
# 18.28
# 24.71
# 21.16
# 28.97
# 22.49
# 5.75
# 16.32
# 22.75
# 40.17
# 27.28
# 12.03
# 21.01
# 12.46
# 11.35
# 15.38
# 44.3
# 22.42
# 20.92
# 15.36
# 20.49
# 25.21
# 18.24
# 14.31
# 14.0
# 7.25
# 38.07
# 23.95
# 25.71
# 17.31
# 29.93
# 10.65
# 12.43
# 24.08
# 11.69
# 13.42
# 14.26
# 15.95
# 12.48
# 29.8
# ...

# %%
for a in df['total_bill']:
  if a > 1 and a <= 10 :
    print("Eco")
  elif a > 10 and a <= 20:
    print("Business")
  elif a > 20 and a <= 30:
    print("First")
  else:
    print("Premium")
# Out:
# Business
# Business
# First
# First
# First
# First
# Eco
# First
# Business
# Business
# Business
# Premium
# Business
# Business
# Business
# First
# Business
# Business
# Business
# First
# Business
# First
# Business
# Premium
# Business
# Business
# Business
# Business
# First
# Business
# Eco
# Business
# Business
# First
# Business
# First
# Business
# Business
# Business
# Premium
# Business
# Business
# Business
# Eco
# Premium
# Business
# First
# Premium
# First
# Business
# Business
# Business
# Premium
# Eco
# First
# Business
# Premium
# First
# Business
# Premium
# First
# Business
# Business
# Business
# Business
# First
# Business
# Eco
# First
# Business
# Business
# Business
# First
# First
# Business
# Business
# Business
# First
# First
# Business
# Business
# Business
# Business
# Premium
# Business
# Premium
# Business
# Business
# First
# First
# First
# First
# Eco
# Business
# First
# Premium
# First
# Business
# First
# Business
# Business
# Business
# ...

# %%
import seaborn as sb
sb.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = sb.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
range(0,10,1)
# Out:
# range(0, 10)

# %%
range
# Out:
# range

# %%
a = []
for i in range(0,10,2):
  a.append(i)

# %%
a
# Out:
# [0, 2, 4, 6, 8]

# %%
a = []
for i in range(0,10,2):
  a.append(i)
  print(a)
# Out:
# [0]
# [0, 2]
# [0, 2, 4]
# [0, 2, 4, 6]
# [0, 2, 4, 6, 8]

# %%
b = []
for i in ["hello","hi"]:
  b.upper(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-da2312386c72> in <cell line: 2>()
#       1 b = []
#       2 for i in ["hello","hi"]:
# ----> 3   b.upper(i)
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
for a,b in [['a','b'],[100,200]]:
  print(a)
  print(b)
# Out:
# a
# b
# 100
# 200

# %%
print(b)
# Out:
# 200

# %%
a = [ 'car' ,'train']
b = [100 ,200 ]

# %%
zip(a,b)

# %%
list('<zip at 0x7b844f81afc0>')
# Out:
# ['<',
#  'z',
#  'i',
#  'p',
#  ' ',
#  'a',
#  't',
#  ' ',
#  '0',
#  'x',
#  '7',
#  'b',
#  '8',
#  '4',
#  '4',
#  'f',
#  '8',
#  '1',
#  'a',
#  'f',
#  'c',
#  '0',
#  '>']

# %%
for i in zip(a,b):
  print(i)
# Out:
# ('car', 100)
# ('train', 200)

# %%
def change(x):
  return x.lower()

# %%
change('HLA')
# Out:
# 'hla'

# %%
change('MYO')
# Out:
# 'myo'

# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/top_10_countries.csv')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/top_10_countries.csv')

# %%
df
# Out:
#    Rank Country / Dependency    Region    Population % of world       Date
# 0     1                China      Asia  1.412600e+09     17.80%  31-Dec-21
# 1     2                India      Asia  1.386947e+09     17.50%  18-Jan-22
# 2     3        United States  Americas  3.330732e+08      4.20%  18-Jan-22
# 3     4         Indonesia[b]      Asia  2.713500e+08      3.42%  31-Dec-20
# 4     5             Pakistan      Asia  2.252000e+08      2.84%  01-Jul-21
# 5     6               Brazil  Americas  2.142316e+08      2.70%  18-Jan-22
# 6     7              Nigeria    Africa  2.114010e+08      2.67%  01-Jul-21
# 7     8           Bangladesh      Asia  1.720626e+08      2.17%  18-Jan-22
# 8     9            Russia[b]    Europe  1.461710e+08      1.84%  01-Jan-21
# 9    10               Mexico  Americas  1.260140e+08      1.59%  02-Mar-20

# %%
df['region']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-7d205cd930da> in <cell line: 1>()
# ----> 1 df['region']
#
# ...

# %%
df.iloc[1,2]
# Out:
# 'Asia'

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/Pandas_EX1.csv')

# %%
df
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df[::-1]
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# ...            ...                  ...            ...    ...
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 29998    dalton37@adventure-works.com     $90,000                      2
# ...

# %%
df.tail(1)
# Out:
#          OrderDate              Name    BirthDate Gender  \
# 29998  2/4/17 0:00  MR. DALTON PEREZ  4/4/57 0:00      M
#
#                        EmailAddress AnnualIncome  Sum of TotalChildren  \
# 29998  dalton37@adventure-works.com     $90,000                      2
#
#         EducationLevel    Occupation HomeOwner  ...  \
# 29998  Partial College  Professional         Y  ...
#
#                                       ProductDescription ProductColor  \
# 29998  Universal fit, well-vented, lightweight , snap...        Black
#
#       ProductSize ProductStyle Sum of ProductPrice Sum of OrderQuantity  \
# 29998           0            0             33.6442                    1
#
#        SubcategoryName  Region Country      Continent
# 29998          Helmets  Canada  Canada  North America
#
# [1 rows x 22 columns]

# %%
(df['Gender']== 'M') & (df['Sum of TotalChildren'] > 3)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29994    False
# 29995    False
# 29996     True
# 29997     True
# 29998    False
# Length: 29999, dtype: bool

# %%
df[(df['Gender']== 'M') & (df['Sum of TotalChildren'] > 3)]
# Out:
#          OrderDate                Name      BirthDate Gender  \
# 17     1/4/15 0:00  MR. RICHARD PARKER  11/15/58 0:00      M
# 21     1/5/15 0:00   MR. ADAM PHILLIPS   9/13/46 0:00      M
# 23     1/5/15 0:00    MR. MIGUEL GREEN   7/22/60 0:00      M
# 30     1/7/15 0:00      MR. BRENDAN XU  11/23/66 0:00      M
# 34     1/8/15 0:00       MR. ADAM HILL    9/4/58 0:00      M
# ...            ...                 ...            ...    ...
# 29899  2/3/17 0:00    MR. JUSTIN SMITH   3/11/64 0:00      M
# 29920  2/3/17 0:00   MR. WILLIAM MOORE    3/2/50 0:00      M
# 29921  2/3/17 0:00   MR. WILLIAM MOORE    3/2/50 0:00      M
# 29996  2/4/17 0:00     MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00     MR. CONNOR KING   3/12/60 0:00      M
#
#                         EmailAddress AnnualIncome  Sum of TotalChildren  \
# 17     richard36@adventure-works.com     $80,000                      5
# 21        adam36@adventure-works.com     $70,000                      5
# ...

# %%
 df[(df['Gender']== 'F') & (df['Occupation'] == 'Management')]
# Out:
#           OrderDate                    Name      BirthDate Gender  \
# 28      1/6/15 0:00      MRS. TAYLOR THOMAS   5/15/53 0:00      F
# 40      1/8/15 0:00  MRS. VICTORIA GONZALES   7/17/70 0:00      F
# 47     1/10/15 0:00          MRS. DAWN NATH  11/22/69 0:00      F
# 55     1/11/15 0:00       MRS. RILEY BROOKS   1/27/36 0:00      F
# 62     1/12/15 0:00        MRS. JANET SCOTT   8/18/53 0:00      F
# ...             ...                     ...            ...    ...
# 29783   2/1/17 0:00     MRS. VICTORIA SMITH   1/19/61 0:00      F
# 29784   2/1/17 0:00     MRS. VICTORIA SMITH   1/19/61 0:00      F
# 29785   2/1/17 0:00     MRS. VICTORIA SMITH   1/19/61 0:00      F
# 29952   2/3/17 0:00           MRS. LEAH CAI   5/20/58 0:00      F
# 29953   2/3/17 0:00           MRS. LEAH CAI   5/20/58 0:00      F
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 28       taylor58@adventure-works.com     $70,000                      3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# OrderDate                   0
# Name                        0
# BirthDate                   0
# Gender                    200
# EmailAddress                0
# AnnualIncome                0
# Sum of TotalChildren        0
# EducationLevel              0
# Occupation                  0
# HomeOwner                   0
# ProductSKU                  0
# ProductName                 0
# ProductDescription          0
# ProductColor            13632
# ProductSize                 0
# ProductStyle                0
# Sum of ProductPrice         0
# Sum of OrderQuantity        0
# SubcategoryName             0
# Region                      0
# Country                     0
# Continent                   0
# dtype: int64

# %%
df['ProductColor'].fillna('No Color',inplace=True)

# %%
pd.to_datetime(df['BirthDate'])
# Out:
# <ipython-input-36-5d684a994bbf>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['BirthDate'])
# 0       2058-11-11
# 1       2055-04-11
# 2       1974-04-21
# 3       1980-09-25
# 4       2065-01-11
#            ...
# 29994   1976-07-08
# 29995   1976-07-08
# 29996   2060-03-12
# 29997   2060-03-12
# 29998   2057-04-04
# Name: BirthDate, Length: 29999, dtype: datetime64[ns]

# %%
df
# Out:
# <ipython-input-37-c88251551769>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['BirthDate'] = pd.to_datetime(df['BirthDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  datetime64[ns]
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
pd.to_datetime(df['OrderDate'])
# Out:
# <ipython-input-39-5bbaff556be4>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['OrderDate'])
# 0       2015-01-01
# 1       2015-01-01
# 2       2015-01-01
# 3       2015-01-01
# 4       2015-01-02
#            ...
# 29994   2017-02-04
# 29995   2017-02-04
# 29996   2017-02-04
# 29997   2017-02-04
# 29998   2017-02-04
# Name: OrderDate, Length: 29999, dtype: datetime64[ns]

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'])
# Out:
# <ipython-input-40-b3b3d15d6267>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['OrderDate'] = pd.to_datetime(df['OrderDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  datetime64[ns]
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
df['order_year'] = df['OrderDate'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  datetime64[ns]
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
df[df['OrderDate'] == df['OrderDate'].dt.month]
# Out:
# Empty DataFrame
# Columns: [OrderDate, Name, BirthDate, Gender, EmailAddress, AnnualIncome, Sum of TotalChildren, EducationLevel, Occupation, HomeOwner, ProductSKU, ProductName, ProductDescription, ProductColor, ProductSize, ProductStyle, Sum of ProductPrice, Sum of OrderQuantity, SubcategoryName, Region, Country, Continent, order_year]
# Index: []
#
# [0 rows x 23 columns]

# %%
df[df['order_year'] == df['OrderDate'].dt.year]
# Out:
# Empty DataFrame
# Columns: [OrderDate, Name, BirthDate, Gender, EmailAddress, AnnualIncome, Sum of TotalChildren, EducationLevel, Occupation, HomeOwner, ProductSKU, ProductName, ProductDescription, ProductColor, ProductSize, ProductStyle, Sum of ProductPrice, Sum of OrderQuantity, SubcategoryName, Region, Country, Continent, order_year]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.split('OrderDate')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-a30ada44809e> in <cell line: 1>()
# ----> 1 df.split('OrderDate')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'split'

# %%
df['year'] == df['OrderDate'].dt.year()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-8bf5452ac8e7> in <cell line: 1>()
# ----> 1 df['year'] == df['OrderDate'].dt.year()
#
# ...

# %%
df.drop(columns = ['ProductsDescription','ProductStyle','ProductSize'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-d20a3f735335> in <cell line: 1>()
# ----> 1 df.drop(columns = ['ProductsDescription','ProductStyle','ProductSize'],inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  datetime64[ns]
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductName           29999 non-null  object
#  11  ProductDescription    29999 non-null  object
#  12  ProductColor          29999 non-null  object
#  13  ProductSize           29999 non-null  object
# ...

# %%
df.rename(columns={'Sum of TotalChildren':'TotalChildren'},inplace=True)

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/tfl-daily-cycle-hires.csv')

# %%
df
# Out:
#              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]

# %%
df['Day'].sort_values(by='Number of Bicycle Hires',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-a4b7d84e6e90> in <cell line: 1>()
# ----> 1 df['Day'].sort_values(by='Number of Bicycle Hires',ascending=False)
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/top_10_countries.csv')
# Out:
#    Rank Country / Dependency    Region    Population % of world       Date
# 0     1                China      Asia  1.412600e+09     17.80%  31-Dec-21
# 1     2                India      Asia  1.386947e+09     17.50%  18-Jan-22
# 2     3        United States  Americas  3.330732e+08      4.20%  18-Jan-22
# 3     4         Indonesia[b]      Asia  2.713500e+08      3.42%  31-Dec-20
# 4     5             Pakistan      Asia  2.252000e+08      2.84%  01-Jul-21
# 5     6               Brazil  Americas  2.142316e+08      2.70%  18-Jan-22
# 6     7              Nigeria    Africa  2.114010e+08      2.67%  01-Jul-21
# 7     8           Bangladesh      Asia  1.720626e+08      2.17%  18-Jan-22
# 8     9            Russia[b]    Europe  1.461710e+08      1.84%  01-Jan-21
# 9    10               Mexico  Americas  1.260140e+08      1.59%  02-Mar-20

# %%
df=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/top_10_countries.csv')

# %%
df
# Out:
#    Rank Country / Dependency    Region    Population % of world       Date
# 0     1                China      Asia  1.412600e+09     17.80%  31-Dec-21
# 1     2                India      Asia  1.386947e+09     17.50%  18-Jan-22
# 2     3        United States  Americas  3.330732e+08      4.20%  18-Jan-22
# 3     4         Indonesia[b]      Asia  2.713500e+08      3.42%  31-Dec-20
# 4     5             Pakistan      Asia  2.252000e+08      2.84%  01-Jul-21
# 5     6               Brazil  Americas  2.142316e+08      2.70%  18-Jan-22
# 6     7              Nigeria    Africa  2.114010e+08      2.67%  01-Jul-21
# 7     8           Bangladesh      Asia  1.720626e+08      2.17%  18-Jan-22
# 8     9            Russia[b]    Europe  1.461710e+08      1.84%  01-Jan-21
# 9    10               Mexico  Americas  1.260140e+08      1.59%  02-Mar-20

# %%
df['Region']
# Out:
# 0        Asia
# 1        Asia
# 2    Americas
# 3        Asia
# 4        Asia
# 5    Americas
# 6      Africa
# 7        Asia
# 8      Europe
# 9    Americas
# Name: Region, dtype: object

# %%
df['Region']
# Out:
# 0        Asia
# 1        Asia
# 2    Americas
# 3        Asia
# 4        Asia
# 5    Americas
# 6      Africa
# 7        Asia
# 8      Europe
# 9    Americas
# Name: Region, dtype: object

# %%
df[['Rank','Region']]
# Out:
#    Rank    Region
# 0     1      Asia
# 1     2      Asia
# 2     3  Americas
# 3     4      Asia
# 4     5      Asia
# 5     6  Americas
# 6     7    Africa
# 7     8      Asia
# 8     9    Europe
# 9    10  Americas

# %%
df
# Out:
#    Rank Country / Dependency    Region    Population % of world       Date
# 0     1                China      Asia  1.412600e+09     17.80%  31-Dec-21
# 1     2                India      Asia  1.386947e+09     17.50%  18-Jan-22
# 2     3        United States  Americas  3.330732e+08      4.20%  18-Jan-22
# 3     4         Indonesia[b]      Asia  2.713500e+08      3.42%  31-Dec-20
# 4     5             Pakistan      Asia  2.252000e+08      2.84%  01-Jul-21
# 5     6               Brazil  Americas  2.142316e+08      2.70%  18-Jan-22
# 6     7              Nigeria    Africa  2.114010e+08      2.67%  01-Jul-21
# 7     8           Bangladesh      Asia  1.720626e+08      2.17%  18-Jan-22
# 8     9            Russia[b]    Europe  1.461710e+08      1.84%  01-Jan-21
# 9    10               Mexico  Americas  1.260140e+08      1.59%  02-Mar-20

# %%
type(df[['Rank','Region']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a74c58233b9e> in <cell line: 1>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/Pandas_EX1.csv')
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/Pandas_EX1.csv')

# %%
df
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df['OrderDate']
# Out:
# 0        1/1/15 0:00
# 1        1/1/15 0:00
# 2        1/1/15 0:00
# 3        1/1/15 0:00
# 4        1/2/15 0:00
#             ...
# 29994    2/4/17 0:00
# 29995    2/4/17 0:00
# 29996    2/4/17 0:00
# 29997    2/4/17 0:00
# 29998    2/4/17 0:00
# Name: OrderDate, Length: 29999, dtype: object

# %%
df[['OrderDate','Name']]
# Out:
#          OrderDate                 Name
# 0      1/1/15 0:00      MR. JOHN THOMAS
# 1      1/1/15 0:00  MR. KYLE WASHINGTON
# 2      1/1/15 0:00        MR. ROSS SANZ
# 3      1/1/15 0:00       MR. SETH LEWIS
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN
# ...            ...                  ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI
# 29995  2/4/17 0:00      MR. CLAYTON JAI
# 29996  2/4/17 0:00      MR. CONNOR KING
# 29997  2/4/17 0:00      MR. CONNOR KING
# 29998  2/4/17 0:00     MR. DALTON PEREZ
#
# [29999 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df.iloc[1]
# Out:
# OrderDate                                                     1/1/15 0:00
# Name                                                  MR. KYLE WASHINGTON
# BirthDate                                                    4/11/55 0:00
# Gender                                                                  M
# EmailAddress                                    kyle8@adventure-works.com
# AnnualIncome                                                     $80,000
# Sum of TotalChildren                                                    3
# EducationLevel                                            Partial College
# Occupation                                                   Professional
# HomeOwner                                                               N
# ProductSKU                                                     BK-R93R-48
# ProductName                                              Road-150 Red, 48
# ProductDescription      This bike is ridden by race winners. Developed...
# ...

# %%
df.iloc[1:3]
# Out:
#      OrderDate                 Name     BirthDate Gender  \
# 1  1/1/15 0:00  MR. KYLE WASHINGTON  4/11/55 0:00      M
# 2  1/1/15 0:00        MR. ROSS SANZ  4/21/74 0:00      M
#
#                  EmailAddress AnnualIncome  Sum of TotalChildren  \
# 1   kyle8@adventure-works.com     $80,000                      3
# 2  ross38@adventure-works.com    $100,000                      0
#
#     EducationLevel    Occupation HomeOwner  ...  \
# 1  Partial College  Professional         N  ...
# 2      High School    Management         Y  ...
#
#                                   ProductDescription ProductColor ProductSize  \
# 1  This bike is ridden by race winners. Developed...          Red          48
# 2  Top-of-the-line competition mountain bike. Per...        Black          44
#
#   ProductStyle Sum of ProductPrice Sum of OrderQuantity  SubcategoryName  \
# 1            U             3578.27                    1       Road Bikes
# ...

# %%
df
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df.head(5)
# Out:
#      OrderDate                 Name      BirthDate Gender  \
# 0  1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1  1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2  1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3  1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4  1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
#
#                      EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0      john48@adventure-works.com     $80,000                      1
# 1       kyle8@adventure-works.com     $80,000                      3
# 2      ross38@adventure-works.com    $100,000                      0
# 3      seth20@adventure-works.com     $30,000                      0
# 4  alejandro4@adventure-works.com     $20,000                      2
#
#     EducationLevel      Occupation HomeOwner  ...  \
# 0  Partial College  Skilled Manual         N  ...
# 1  Partial College    Professional         N  ...
# ...

# %%
df.iloc[1,4]
# Out:
# 'kyle8@adventure-works.com'

# %%
df.iloc[3,7]
# Out:
# 'High School'

# %%
df
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df.loc[1,'BirthDate']
# Out:
# '4/11/55 0:00'

# %%
df.loc[29995,'EmailAddress']
# Out:
# 'clayton29@adventure-works.com'

# %%
df.iloc[29995,4]
# Out:
# 'clayton29@adventure-works.com'

# %%
df[df['EducationLevel']== 'High School']
# Out:
#          OrderDate                     Name      BirthDate Gender  \
# 2      1/1/15 0:00            MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00           MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00       MR. ALEJANDRO CHEN   1/11/65 0:00      M
# 12     1/3/15 0:00  MRS. ADRIENNE GUTIERREZ   4/13/52 0:00      F
# 16     1/4/15 0:00      MR. GEORGE MCDONALD  10/23/69 0:00      M
# ...            ...                      ...            ...    ...
# 29966  2/3/17 0:00       MS. HANNAH JACKSON    2/6/75 0:00      F
# 29967  2/3/17 0:00       MS. HANNAH JACKSON    2/6/75 0:00      F
# 29972  2/3/17 0:00      MS. MADELINE CARTER    8/4/74 0:00      F
# 29996  2/4/17 0:00          MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00          MR. CONNOR KING   3/12/60 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 2          ross38@adventure-works.com    $100,000                      0
# ...

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
df['Gender']== 'M'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 29994    True
# 29995    True
# 29996    True
# 29997    True
# 29998    True
# Name: Gender, Length: 29999, dtype: bool

# %%
df[df['Gender']=='M']
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df[(df['Gender']=='M') and (df['AnnualIncome'] == 8000)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-1b05f4a9fc86> in <cell line: 1>()
# ----> 1 df[(df['Gender']=='M') and (df['AnnualIncome'] == 8000)]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[(df['Gender']=='M') & (df['AnnualIncome'] == 8000)]
# Out:
# Empty DataFrame
# Columns: [OrderDate, Name, BirthDate, Gender, EmailAddress, AnnualIncome, Sum of TotalChildren, EducationLevel, Occupation, HomeOwner, ProductSKU, ProductName, ProductDescription, ProductColor, ProductSize, ProductStyle, Sum of ProductPrice, Sum of OrderQuantity, SubcategoryName, Region, Country, Continent]
# Index: []
#
# [0 rows x 22 columns]

# %%
df[df['AnnualIncome'] > 8000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-f74f04d6912a> in <cell line: 1>()
# ----> 1 df[df['AnnualIncome'] > 8000]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5801         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5802
# ...

# %%
df
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df['AnnualIncome']>8000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-0d266ff15cbb> in <cell line: 1>()
# ----> 1 df['AnnualIncome']>8000
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5801         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5802
# ...

# %%
df[df['AnnualIncome']>=80000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-bbce521e5373> in <cell line: 1>()
# ----> 1 df[df['AnnualIncome']>=80000]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __ge__(self, other)
#      58     @unpack_zerodim_and_defer("__ge__")
#      59     def __ge__(self, other):
# ---> 60         return self._cmp_method(other, operator.ge)
#      61
#      62     # -------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
# ...

# %%
df
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df[(df['AnnualIncome']=='80000')]
# Out:
# Empty DataFrame
# Columns: [OrderDate, Name, BirthDate, Gender, EmailAddress, AnnualIncome, Sum of TotalChildren, EducationLevel, Occupation, HomeOwner, ProductSKU, ProductName, ProductDescription, ProductColor, ProductSize, ProductStyle, Sum of ProductPrice, Sum of OrderQuantity, SubcategoryName, Region, Country, Continent]
# Index: []
#
# [0 rows x 22 columns]

# %%
df['AnnualIncome'].unique()
# Out:
# array(['$80,000 ', '$100,000 ', '$30,000 ', '$20,000 ', '$70,000 ',
#        '$60,000 ', '$40,000 ', '$10,000 ', '$120,000 ', '$130,000 ',
#        '$170,000 ', '$90,000 ', '$110,000 ', '$160,000 ', '$150,000 ',
#        '$50,000 '], dtype=object)

# %%
df [(df['Gender']=='M') & (df['AnnualIncome'] == 80000)]
# Out:
# Empty DataFrame
# Columns: [OrderDate, Name, BirthDate, Gender, EmailAddress, AnnualIncome, Sum of TotalChildren, EducationLevel, Occupation, HomeOwner, ProductSKU, ProductName, ProductDescription, ProductColor, ProductSize, ProductStyle, Sum of ProductPrice, Sum of OrderQuantity, SubcategoryName, Region, Country, Continent]
# Index: []
#
# [0 rows x 22 columns]

# %%
df[(df['Gender']== 'M' ) & (df['Sum of TotalChildren']>3)]
# Out:
#          OrderDate                Name      BirthDate Gender  \
# 17     1/4/15 0:00  MR. RICHARD PARKER  11/15/58 0:00      M
# 21     1/5/15 0:00   MR. ADAM PHILLIPS   9/13/46 0:00      M
# 23     1/5/15 0:00    MR. MIGUEL GREEN   7/22/60 0:00      M
# 30     1/7/15 0:00      MR. BRENDAN XU  11/23/66 0:00      M
# 34     1/8/15 0:00       MR. ADAM HILL    9/4/58 0:00      M
# ...            ...                 ...            ...    ...
# 29899  2/3/17 0:00    MR. JUSTIN SMITH   3/11/64 0:00      M
# 29920  2/3/17 0:00   MR. WILLIAM MOORE    3/2/50 0:00      M
# 29921  2/3/17 0:00   MR. WILLIAM MOORE    3/2/50 0:00      M
# 29996  2/4/17 0:00     MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00     MR. CONNOR KING   3/12/60 0:00      M
#
#                         EmailAddress AnnualIncome  Sum of TotalChildren  \
# 17     richard36@adventure-works.com     $80,000                      5
# 21        adam36@adventure-works.com     $70,000                      5
# ...

# %%
df[(df['Gender']== 'M' ) & (df['AnnualIncome']>80000)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-5a83fa4ee751> in <cell line: 1>()
# ----> 1 df[(df['Gender']== 'M' ) & (df['AnnualIncome']>80000)]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# OrderDate                   0
# Name                        0
# BirthDate                   0
# Gender                    200
# EmailAddress                0
# AnnualIncome                0
# Sum of TotalChildren        0
# EducationLevel              0
# Occupation                  0
# HomeOwner                   0
# ProductSKU                  0
# ProductName                 0
# ProductDescription          0
# ProductColor            13632
# ProductSize                 0
# ProductStyle                0
# Sum of ProductPrice         0
# Sum of OrderQuantity        0
# SubcategoryName             0
# Region                      0
# Country                     0
# Continent                   0
# dtype: int64

# %%
df[df['Gender'].isna()]
# Out:
#           OrderDate                 Name     BirthDate Gender  \
# 153    1/27/15 0:00          RICKY GOMEZ  7/21/59 0:00    NaN
# 235     2/9/15 0:00      HAROLD MCDONALD  5/23/60 0:00    NaN
# 409    3/10/15 0:00         ANGELA PERRY  6/27/73 0:00    NaN
# 555     4/3/15 0:00          DENNIS WARE  10/4/50 0:00    NaN
# 639    4/16/15 0:00   VANESSA WASHINGTON  4/14/73 0:00    NaN
# ...             ...                  ...           ...    ...
# 29427  1/30/17 0:00        MISTY CHANDER  4/17/57 0:00    NaN
# 29850   2/3/17 0:00          GAIL BUTLER  2/24/58 0:00    NaN
# 29851   2/3/17 0:00          GAIL BUTLER  2/24/58 0:00    NaN
# 29852   2/3/17 0:00          GAIL BUTLER  2/24/58 0:00    NaN
# 29853   2/3/17 0:00          GAIL BUTLER  2/24/58 0:00    NaN
#
#                         EmailAddress AnnualIncome  Sum of TotalChildren  \
# 153       ricky1@adventure-works.com    $100,000                      5
# 235     harold11@adventure-works.com     $20,000                      1
# ...

# %%
df['Gender'].fillna('Not Defined',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# OrderDate                   0
# Name                        0
# BirthDate                   0
# Gender                    200
# EmailAddress                0
# AnnualIncome                0
# Sum of TotalChildren        0
# EducationLevel              0
# Occupation                  0
# HomeOwner                   0
# ProductSKU                  0
# ProductName                 0
# ProductDescription          0
# ProductColor            13632
# ProductSize                 0
# ProductStyle                0
# Sum of ProductPrice         0
# Sum of OrderQuantity        0
# SubcategoryName             0
# Region                      0
# Country                     0
# Continent                   0
# dtype: int64

# %%
df['ProductColor'].fillna('No Color',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# OrderDate               0
# Name                    0
# BirthDate               0
# Gender                  0
# EmailAddress            0
# AnnualIncome            0
# Sum of TotalChildren    0
# EducationLevel          0
# Occupation              0
# HomeOwner               0
# ProductSKU              0
# ProductName             0
# ProductDescription      0
# ProductColor            0
# ProductSize             0
# ProductStyle            0
# Sum of ProductPrice     0
# Sum of OrderQuantity    0
# SubcategoryName         0
# Region                  0
# Country                 0
# Continent               0
# dtype: int64

# %%
df.describe()
# Out:
#        Sum of TotalChildren  Sum of ProductPrice  Sum of OrderQuantity
# count          29999.000000         29999.000000          29999.000000
# mean               1.836095           552.213093              1.474416
# std                1.624114           954.975675              0.606983
# min                0.000000             2.290000              1.000000
# 25%                0.000000             8.644200              1.000000
# 50%                2.000000            33.644200              1.000000
# 75%                3.000000           699.098200              2.000000
# max               10.000000          3578.270000              4.000000

# %%
df
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df['OrderDate'].astype('datetime64[ns]')
# Out:
# <ipython-input-78-4d83b4d69f4b>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['OrderDate'].astype('datetime64[ns]')
# 0       2015-01-01
# 1       2015-01-01
# 2       2015-01-01
# 3       2015-01-01
# 4       2015-01-02
#            ...
# 29994   2017-02-04
# 29995   2017-02-04
# 29996   2017-02-04
# 29997   2017-02-04
# 29998   2017-02-04
# Name: OrderDate, Length: 29999, dtype: datetime64[ns]

# %%
df
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df['OrderDate'].astype('datetime64[ns]')
# Out:
# <ipython-input-82-4d83b4d69f4b>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['OrderDate'].astype('datetime64[ns]')
# 0       2015-01-01
# 1       2015-01-01
# 2       2015-01-01
# 3       2015-01-01
# 4       2015-01-02
#            ...
# 29994   2017-02-04
# 29995   2017-02-04
# 29996   2017-02-04
# 29997   2017-02-04
# 29998   2017-02-04
# Name: OrderDate, Length: 29999, dtype: datetime64[ns]

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'])
# Out:
# <ipython-input-83-b3b3d15d6267>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['OrderDate'] = pd.to_datetime(df['OrderDate'])

# %%
pd.to_datetime(df['OrderDate'])
# Out:
# 0       2015-01-01
# 1       2015-01-01
# 2       2015-01-01
# 3       2015-01-01
# 4       2015-01-02
#            ...
# 29994   2017-02-04
# 29995   2017-02-04
# 29996   2017-02-04
# 29997   2017-02-04
# 29998   2017-02-04
# Name: OrderDate, Length: 29999, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
pd.to_datetime(df['BirthDate'])
# Out:
# <ipython-input-89-5d684a994bbf>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['BirthDate'])
# 0       2058-11-11
# 1       2055-04-11
# 2       1974-04-21
# 3       1980-09-25
# 4       2065-01-11
#            ...
# 29994   1976-07-08
# 29995   1976-07-08
# 29996   2060-03-12
# 29997   2060-03-12
# 29998   2057-04-04
# Name: BirthDate, Length: 29999, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
df['BirthDate'].astype('datetime64[ns]')
# Out:
# <ipython-input-93-e5a2ab618a0c>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['BirthDate'].astype('datetime64[ns]')
# 0       2058-11-11
# 1       2055-04-11
# 2       1974-04-21
# 3       1980-09-25
# 4       2065-01-11
#            ...
# 29994   1976-07-08
# 29995   1976-07-08
# 29996   2060-03-12
# 29997   2060-03-12
# 29998   2057-04-04
# Name: BirthDate, Length: 29999, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
df['BirhtDate']=pd.to_datetime(df['BirthDate'])
# Out:
# <ipython-input-97-d5396672b8c0>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['BirhtDate']=pd.to_datetime(df['BirthDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
pd.to_datetime(df['BirthDate'])
# Out:
# <ipython-input-100-5d684a994bbf>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['BirthDate'])
# 0       2058-11-11
# 1       2055-04-11
# 2       1974-04-21
# 3       1980-09-25
# 4       2065-01-11
#            ...
# 29994   1976-07-08
# 29995   1976-07-08
# 29996   2060-03-12
# 29997   2060-03-12
# 29998   2057-04-04
# Name: BirthDate, Length: 29999, dtype: datetime64[ns]

# %%
df['BirthDate'] = pd.to_datetime(df['BirthDate'])
# Out:
# <ipython-input-102-c88251551769>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['BirthDate'] = pd.to_datetime(df['BirthDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  datetime64[ns]
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
df['OrderDate'].dt.year
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 29994    2017
# 29995    2017
# 29996    2017
# 29997    2017
# 29998    2017
# Name: OrderDate, Length: 29999, dtype: int32

# %%
df['OrderDate'].dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 29994    2
# 29995    2
# 29996    2
# 29997    2
# 29998    2
# Name: OrderDate, Length: 29999, dtype: int32

# %%
df['OrderDate'].dt.day
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        2
#         ..
# 29994    4
# 29995    4
# 29996    4
# 29997    4
# 29998    4
# Name: OrderDate, Length: 29999, dtype: int32

# %%
df['order_year'] = df['OrderDate'].dt.year

# %%
df
# Out:
#        OrderDate                 Name  BirthDate Gender  \
# 0     2015-01-01      MR. JOHN THOMAS 2058-11-11      M
# 1     2015-01-01  MR. KYLE WASHINGTON 2055-04-11      M
# 2     2015-01-01        MR. ROSS SANZ 1974-04-21      M
# 3     2015-01-01       MR. SETH LEWIS 1980-09-25      M
# 4     2015-01-02   MR. ALEJANDRO CHEN 2065-01-11      M
# ...          ...                  ...        ...    ...
# 29994 2017-02-04      MR. CLAYTON JAI 1976-07-08      M
# 29995 2017-02-04      MR. CLAYTON JAI 1976-07-08      M
# 29996 2017-02-04      MR. CONNOR KING 2060-03-12      M
# 29997 2017-02-04      MR. CONNOR KING 2060-03-12      M
# 29998 2017-02-04     MR. DALTON PEREZ 2057-04-04      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# 1           kyle8@adventure-works.com     $80,000                      3
# ...

# %%
df['Order_month']= df['OrderDate'].dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-8259ae4cfa0a> in <cell line: 1>()
# ----> 1 df['Order_month']= df['OrderDate'].dt.month
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
df
# Out:
#        OrderDate                 Name  BirthDate Gender  \
# 0     2015-01-01      MR. JOHN THOMAS 2058-11-11      M
# 1     2015-01-01  MR. KYLE WASHINGTON 2055-04-11      M
# 2     2015-01-01        MR. ROSS SANZ 1974-04-21      M
# 3     2015-01-01       MR. SETH LEWIS 1980-09-25      M
# 4     2015-01-02   MR. ALEJANDRO CHEN 2065-01-11      M
# ...          ...                  ...        ...    ...
# 29994 2017-02-04      MR. CLAYTON JAI 1976-07-08      M
# 29995 2017-02-04      MR. CLAYTON JAI 1976-07-08      M
# 29996 2017-02-04      MR. CONNOR KING 2060-03-12      M
# 29997 2017-02-04      MR. CONNOR KING 2060-03-12      M
# 29998 2017-02-04     MR. DALTON PEREZ 2057-04-04      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# 1           kyle8@adventure-works.com     $80,000                      3
# ...

# %%
df['Order_month_name']= df['OrderDate'].dt.month_name()

# %%
df
# Out:
#        OrderDate                 Name  BirthDate Gender  \
# 0     2015-01-01      MR. JOHN THOMAS 2058-11-11      M
# 1     2015-01-01  MR. KYLE WASHINGTON 2055-04-11      M
# 2     2015-01-01        MR. ROSS SANZ 1974-04-21      M
# 3     2015-01-01       MR. SETH LEWIS 1980-09-25      M
# 4     2015-01-02   MR. ALEJANDRO CHEN 2065-01-11      M
# ...          ...                  ...        ...    ...
# 29994 2017-02-04      MR. CLAYTON JAI 1976-07-08      M
# 29995 2017-02-04      MR. CLAYTON JAI 1976-07-08      M
# 29996 2017-02-04      MR. CONNOR KING 2060-03-12      M
# 29997 2017-02-04      MR. CONNOR KING 2060-03-12      M
# 29998 2017-02-04     MR. DALTON PEREZ 2057-04-04      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# 1           kyle8@adventure-works.com     $80,000                      3
# ...

# %%
df['Order_Year_Name']= df['OrderDate'].dt.year_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-5ce3ddde6901> in <cell line: 1>()
# ----> 1 df['Order_Year_Name']= df['OrderDate'].dt.year_name()
#
# AttributeError: 'DatetimeProperties' object has no attribute 'year_name'

# %%
df['Order_year_name']= df['OrderDate'].dt.day_name()

# %%
df
# Out:
#        OrderDate                 Name  BirthDate Gender  \
# 0     2015-01-01      MR. JOHN THOMAS 2058-11-11      M
# 1     2015-01-01  MR. KYLE WASHINGTON 2055-04-11      M
# 2     2015-01-01        MR. ROSS SANZ 1974-04-21      M
# 3     2015-01-01       MR. SETH LEWIS 1980-09-25      M
# 4     2015-01-02   MR. ALEJANDRO CHEN 2065-01-11      M
# ...          ...                  ...        ...    ...
# 29994 2017-02-04      MR. CLAYTON JAI 1976-07-08      M
# 29995 2017-02-04      MR. CLAYTON JAI 1976-07-08      M
# 29996 2017-02-04      MR. CONNOR KING 2060-03-12      M
# 29997 2017-02-04      MR. CONNOR KING 2060-03-12      M
# 29998 2017-02-04     MR. DALTON PEREZ 2057-04-04      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# 1           kyle8@adventure-works.com     $80,000                      3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df.drop(columns = ['ProductDescription','ProductSize'],inplace=True)

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a74c58233b9e> in <cell line: 1>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.pivot_table(index='ProductName',columns='Gender',Values='Sum of OrderQuantity',aggfunc='sum')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-9958d6fa4773> in <cell line: 1>()
# ----> 1 df.pivot_table(index='ProductName',columns='Gender',Values='Sum of OrderQuantity',aggfunc='sum')
#
# TypeError: DataFrame.pivot_table() got an unexpected keyword argument 'Values'

# %%
df.pivot_table(index='Occupation',Columns='Gender',values='OrderQuantity',aggfunc='sum')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f167eb11fa91> in <cell line: 1>()
# ----> 1 df.pivot_table(index='Occupation',Columns='Gender',values='OrderQuantity',aggfunc='sum')
#
# NameError: name 'df' is not defined

# %%
df.rename(columns = {'Sum of TotalChildren':'TotalChildren','Sum of TotalPrice':'TotalPrice','Sum of OrderQuantity':'OrderQuantity'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-25041eda6da1> in <cell line: 1>()
# ----> 1 df.rename(columns = {'Sum of TotalChildren':'TotalChildren','Sum of TotalPrice':'TotalPrice','Sum of OrderQuantity':'OrderQuantity'},inplace=True)
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
pd.read_csv('
# Out:
#              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/Pandas_EX1.csv')

# %%
df1
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df1
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df1.rename(columns = {'Sum of TotalChildren' :'TotalChildren' , 'Sum of ProductPrice' : 'ProductPrice','Sum of OrderQuantity' :'OrderQuantity'},inplace=True)

# %%
df1
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  TotalChildren  \
# 0          john48@adventure-works.com     $80,000               1
# 1           kyle8@adventure-works.com     $80,000               3
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  object
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  object
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductSKU          29999 non-null  object
#  11  ProductName         29999 non-null  object
#  12  ProductDescription  29999 non-null  object
#  13  ProductColor        16367 non-null  object
#  14  ProductSize         29999 non-null  object
# ...

# %%
pd.to_datetime(df1['OrderDate'])
# Out:
# <ipython-input-33-bcd3ca83bc6a>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df1['OrderDate'])
# 0       2015-01-01
# 1       2015-01-01
# 2       2015-01-01
# 3       2015-01-01
# 4       2015-01-02
#            ...
# 29994   2017-02-04
# 29995   2017-02-04
# 29996   2017-02-04
# 29997   2017-02-04
# 29998   2017-02-04
# Name: OrderDate, Length: 29999, dtype: datetime64[ns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  object
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  object
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductSKU          29999 non-null  object
#  11  ProductName         29999 non-null  object
#  12  ProductDescription  29999 non-null  object
#  13  ProductColor        16367 non-null  object
#  14  ProductSize         29999 non-null  object
# ...

# %%
df1['OrderDate'] = pd.to_datetime(df1['OrderDate'])
# Out:
# <ipython-input-36-c7b0189b9cce>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['OrderDate'] = pd.to_datetime(df1['OrderDate'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  object
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductSKU          29999 non-null  object
#  11  ProductName         29999 non-null  object
#  12  ProductDescription  29999 non-null  object
#  13  ProductColor        16367 non-null  object
#  14  ProductSize         29999 non-null  object
# ...

# %%
pd.to_datetime(df1['BirthDate'])
# Out:
# <ipython-input-38-8b0ca6c9adb4>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df1['BirthDate'])
# 0       2058-11-11
# 1       2055-04-11
# 2       1974-04-21
# 3       1980-09-25
# 4       2065-01-11
#            ...
# 29994   1976-07-08
# 29995   1976-07-08
# 29996   2060-03-12
# 29997   2060-03-12
# 29998   2057-04-04
# Name: BirthDate, Length: 29999, dtype: datetime64[ns]

# %%
df1['BirthDate'] = pd.to_datetime(df1['BirthDate'])
# Out:
# <ipython-input-39-c6d60f87972a>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['BirthDate'] = pd.to_datetime(df1['BirthDate'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductSKU          29999 non-null  object
#  11  ProductName         29999 non-null  object
#  12  ProductDescription  29999 non-null  object
#  13  ProductColor        16367 non-null  object
#  14  ProductSize         29999 non-null  object
# ...

# %%
df1['OrderDate'].dt.year
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 29994    2017
# 29995    2017
# 29996    2017
# 29997    2017
# 29998    2017
# Name: OrderDate, Length: 29999, dtype: int32

# %%
df1['OrderDate'].dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 29994    2
# 29995    2
# 29996    2
# 29997    2
# 29998    2
# Name: OrderDate, Length: 29999, dtype: int32

# %%
df1['OrderDate'].dt.month_name()
# Out:
# 0         January
# 1         January
# 2         January
# 3         January
# 4         January
#            ...
# 29994    February
# 29995    February
# 29996    February
# 29997    February
# 29998    February
# Name: OrderDate, Length: 29999, dtype: object

# %%
df1['OrderDate'].dt.day
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        2
#         ..
# 29994    4
# 29995    4
# 29996    4
# 29997    4
# 29998    4
# Name: OrderDate, Length: 29999, dtype: int32

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductSKU          29999 non-null  object
#  11  ProductName         29999 non-null  object
#  12  ProductDescription  29999 non-null  object
#  13  ProductColor        16367 non-null  object
#  14  ProductSize         29999 non-null  object
# ...

# %%
df1['OrderYear'] = df1['OrderDate'].dt.year

# %%
df1['OrderMonth'] = df1['OrderDate'].dt.month

# %%
df1['OrderMonthName'] = df1['OrderDate'].dt.month_name()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductSKU          29999 non-null  object
#  11  ProductName         29999 non-null  object
#  12  ProductDescription  29999 non-null  object
#  13  ProductColor        16367 non-null  object
#  14  ProductSize         29999 non-null  object
# ...

# %%
df1.drop(columns = 'ProductSKU',inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductName         29999 non-null  object
#  11  ProductDescription  29999 non-null  object
#  12  ProductColor        16367 non-null  object
#  13  ProductSize         29999 non-null  object
#  14  ProductStyle        29999 non-null  object
# ...

# %%
df1.sort_values(by='OrderQuantity',inplace=True)

# %%
df1
# Out:
#        OrderDate                     Name  BirthDate Gender  \
# 0     2015-01-01          MR. JOHN THOMAS 2058-11-11      M
# 16960 2016-10-29       MR. BRANDON GARCIA 2055-06-20      M
# 16957 2016-10-29     MR. ANGEL RICHARDSON 2053-11-22      M
# 16955 2016-10-28      MS. STACY DOMINGUEZ 2071-04-03      F
# 16954 2016-10-28      MS. STACY DOMINGUEZ 2071-04-03      F
# ...          ...                      ...        ...    ...
# 24250 2016-12-17  MRS. JENNIFER ALEXANDER 2060-01-22      F
# 26224 2016-12-30   MR. CHARLES RICHARDSON 2051-11-07      M
# 20110 2016-11-22      MR. FERNANDO BARNES 2060-03-03      M
# 13919 2016-10-05           MS. APRIL SHAN 2067-09-02      F
# 20577 2016-11-25        MR. RYAN THOMPSON 2040-05-13      M
#
#                          EmailAddress AnnualIncome  TotalChildren  \
# 0          john48@adventure-works.com     $80,000               1
# 16960   brandon39@adventure-works.com     $60,000               2
# ...

# %%
df1.sort_values(by='OrderQuantity',inplace=False)

# %%
df1[['OrderDate','OrderQuantity']].sort_values(by ='OrderQuantity')
# Out:
#        OrderDate  OrderQuantity
# 0     2015-01-01              1
# 7916  2016-08-19              1
# 1835  2015-09-22              1
# 1839  2015-09-23              1
# 1840  2015-09-23              1
# ...          ...            ...
# 9888  2016-09-04              3
# 21581 2016-12-02              3
# 13919 2016-10-05              4
# 20110 2016-11-22              4
# 20577 2016-11-25              4
#
# [29999 rows x 2 columns]

# %%
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/tfl-daily-cycle-hires.csv')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/tfl-daily-cycle-hires.csv')

# %%
df
# Out:
#              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]

# %%
df.sort_values(by='Number of Bicycle Hires',inplace=False)
# Out:
#              Day  Number of Bicycle Hires  Unnamed: 2
# 142   19/12/2010                   2764.0         NaN
# 141   18/12/2010                   2805.0         NaN
# 555   05/02/2012                   3531.0         NaN
# 905   20/01/2013                   3728.0         NaN
# 151   28/12/2010                   3763.0         NaN
# ...          ...                      ...         ...
# 3613  20/06/2020                  64041.0         NaN
# 3606  13/06/2020                  65045.0         NaN
# 3587  25/05/2020                  67034.0         NaN
# 3592  30/05/2020                  70170.0         NaN
# 1805  09/07/2015                  73094.0         NaN
#
# [4081 rows x 3 columns]

# %%
df
# Out:
#              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]

# %%
df.sort_values(by='Number of Bicycle Hires',inplace=False)
# Out:
#              Day  Number of Bicycle Hires  Unnamed: 2
# 142   19/12/2010                   2764.0         NaN
# 141   18/12/2010                   2805.0         NaN
# 555   05/02/2012                   3531.0         NaN
# 905   20/01/2013                   3728.0         NaN
# 151   28/12/2010                   3763.0         NaN
# ...          ...                      ...         ...
# 3613  20/06/2020                  64041.0         NaN
# 3606  13/06/2020                  65045.0         NaN
# 3587  25/05/2020                  67034.0         NaN
# 3592  30/05/2020                  70170.0         NaN
# 1805  09/07/2015                  73094.0         NaN
#
# [4081 rows x 3 columns]

# %%
df
# Out:
#              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]

# %%
df[['Day','Number of Bicycle Hires']].sort_values(by='Number of Bicycle Hires',ascending=False)
# Out:
#              Day  Number of Bicycle Hires
# 1805  09/07/2015                  73094.0
# 3592  30/05/2020                  70170.0
# 3587  25/05/2020                  67034.0
# 3606  13/06/2020                  65045.0
# 3613  20/06/2020                  64041.0
# ...          ...                      ...
# 151   28/12/2010                   3763.0
# 905   20/01/2013                   3728.0
# 555   05/02/2012                   3531.0
# 141   18/12/2010                   2805.0
# 142   19/12/2010                   2764.0
#
# [4081 rows x 2 columns]

# %%
df

# %%
df
# Out:
#              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]

# %%
df1[['OrderDate','OrderQuantity']].groupby(by = 'OrderDate').sum()
# Out:
#             OrderQuantity
# OrderDate
# 2015-01-01              4
# 2015-01-02              4
# 2015-01-03              8
# 2015-01-04              5
# 2015-01-05              3
# ...                   ...
# 2017-01-31            197
# 2017-02-01            216
# 2017-02-02             83
# 2017-02-03            187
# 2017-02-04             35
#
# [765 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['OrderQuantity'].plot(kind='hist', bins=20, title='OrderQuantity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['OrderQuantity'].plot(kind='line', figsize=(8, 4), title='OrderQuantity')
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['OrderDate']
  ys = series['OrderQuantity']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_1.sort_values('OrderDate', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('OrderDate')
_ = plt.ylabel('OrderQuantity')

# %%
from matplotlib import pyplot as plt
_df_0['OrderQuantity'].plot(kind='hist', bins=20, title='OrderQuantity')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import seaborn as sb
df3 = sb.load_dataset('tips')
df3
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df3[['day','total_bill']].groupby(by='day').sum()

# %%
df3[['day','total_bill']].groupby(by='day').count()

# %%
df3[['day','total_bill']].groupby(by='day').count()

# %%
df3

# %%
df3[['day','total_bill']].groupby(by='day').count().ascending=True

# %%
df3

# %%
df3[['total_bill','day']].groupby(by='day').sum()

# %%
df3[['total_bill','day']].groupby(by='day').sum().sort_values(by='total_bill',ascending=False)

# %%
df3[['total_bill','day']].groupby(by='day').sum().sort_values(by='total_bill',ascending=False)

# %%
df3

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29999 entries, 0 to 20577
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductName         29999 non-null  object
#  11  ProductDescription  29999 non-null  object
#  12  ProductColor        16367 non-null  object
#  13  ProductSize         29999 non-null  object
#  14  ProductStyle        29999 non-null  object
# ...

# %%
df1['AnnualIncome']
# Out:
# 0         80,000
# 16960     60,000
# 16957     90,000
# 16955    150,000
# 16954    150,000
#            ...
# 24250     40,000
# 26224     70,000
# 20110     80,000
# 13919     40,000
# 20577    110,000
# Name: AnnualIncome, Length: 29999, dtype: object

# %%
'$800'[1::]
# Out:
# '800'

# %%
'@45'[1::]
# Out:
# '45'

# %%
'@45'[-1:-3:]
# Out:
# ''

# %%
'80%'[:-1]
# Out:
# '80'

# %%
'$34'[1:]
# Out:
# '34'

# %%
'34%'[:-1]
# Out:
# '34'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29999 entries, 0 to 20577
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductName         29999 non-null  object
#  11  ProductDescription  29999 non-null  object
#  12  ProductColor        16367 non-null  object
#  13  ProductSize         29999 non-null  object
#  14  ProductStyle        29999 non-null  object
# ...

# %%
df1['AnnualIncome']= df1['AnnualIncome'].apply(lambda a : a.split('$')[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-90-9ed7a88a8107> in <cell line: 1>()
# ----> 1 df1['AnnualIncome']= df1['AnnualIncome'].apply(lambda a : a.split('$')[1])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4762             args=args,
#    4763             kwargs=kwargs,
# -> 4764         ).apply()
#    4765
#    4766     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1207
#    1208         # self.func is Callable
# -> 1209         return self.apply_standard()
#    1210
#    1211     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1287         #  Categorical (GH51645).
# ...

# %%
df1['AnnualIncome']
# Out:
# 0         80,000
# 16960     60,000
# 16957     90,000
# 16955    150,000
# 16954    150,000
#            ...
# 24250     40,000
# 26224     70,000
# 20110     80,000
# 13919     40,000
# 20577    110,000
# Name: AnnualIncome, Length: 29999, dtype: object

# %%
df1['AnnualIncome']=df1['AnnualIncome'].apply(lambda x : x.replace ( ',' , ''))

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29999 entries, 0 to 20577
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  object
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductName         29999 non-null  object
#  11  ProductDescription  29999 non-null  object
#  12  ProductColor        16367 non-null  object
#  13  ProductSize         29999 non-null  object
#  14  ProductStyle        29999 non-null  object
# ...

# %%
df1['AnnualIncome']=df1['AnnualIncome'].astype('Int64')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29999 entries, 0 to 20577
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  Int64
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductName         29999 non-null  object
#  11  ProductDescription  29999 non-null  object
#  12  ProductColor        16367 non-null  object
#  13  ProductSize         29999 non-null  object
#  14  ProductStyle        29999 non-null  object
# ...

# %%
#Group by annualincome for occupation
df1[['Occupation','AnnualIncome']].groupby(by='Occupation').sum()
# Out:
#                 AnnualIncome
# Occupation
# Clerical           144200000
# Management         506190000
# Manual              55290000
# Professional       723090000
# Skilled Manual     377960000

# %%
df1[['Country','TotalChildren','AnnualIncome']].groupby(by = 'Country').sum()
# Out:
#                 TotalChildren  AnnualIncome
# Country
# Australia               10490     462610000
# Canada                   7622     221740000
# France                   4919     110760000
# Germany                  4823     132440000
# United Kingdom           5951     193670000
# United States           21276     685510000

# %%
df1[['Country','TotalChildren','AnnualIncome']].groupby(by = ['Country','TotalChildren']).sum().sort_values(by='TotalChildren',ascending=False)
# Out:
#                               AnnualIncome
# Country        TotalChildren
# Canada         10                    80000
# United Kingdom 6                    150000
# Canada         5                  23600000
# United Kingdom 5                  11390000
# Germany        5                   7950000
# France         5                  20390000
# United States  5                  62150000
# Australia      5                  47630000
# United Kingdom 4                  48570000
# France         4                  16930000
# Canada         4                  52890000
# United States  4                 108660000
# Germany        4                  20570000
# Australia      4                  26210000
#                3                  24040000
# Germany        3                  32400000
# United Kingdom 3                  37350000
# France         3                  11750000
# United States  3                  91850000
# Canada         3                  14020000
# ...

# %%
import Pandas as Pd
pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/Pandas_EX1.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-114-bb7d9150d317> in <cell line: 1>()
# ----> 1 import Pandas as Pd
#       2 pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/Pandas_EX1.csv')
#
# ModuleNotFoundError: No module named 'Pandas'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Practise function remove
import pandas as pd
p1=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/Pandas_EX1.csv')

# %%
p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
def splitreplacedatatype(x):
  x = x.split('$')[1]
  x = x.replace(',','')
  x = int(x)
  return x

# %%
splitreplacedatatype('$400,000')
# Out:
# 400000

# %%
def splitreplacedatatype1(x):
  x = x.split('%')[0]
  x = x.replace(',','')
  x = int(x)
  return x

# %%
splitreplacedatatype1('80%')
# Out:
# 80

# %%
splitreplacedatatype('$80,000')
# Out:
# 80000

# %%
p1['AnnualIncome'] = p1['AnnualIncome'].apply(splitreplacedatatype)

# %%
p1['AnnualIncome']
# Out:
# 0         80000
# 1         80000
# 2        100000
# 3         30000
# 4         20000
#           ...
# 29994     70000
# 29995     70000
# 29996    120000
# 29997    120000
# 29998     90000
# Name: AnnualIncome, Length: 29999, dtype: int64

# %%
p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  int64
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
p1
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress  AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com         80000                     1
# ...

# %%
p1[['Region','AnnualIncome']].groupby(by='Region').sum().sort_values(by='AnnualIncome',ascending=False)
# Out:
#                 AnnualIncome
# Region
# Australia          462610000
# Southwest          414770000
# Northwest          268810000
# Canada             221740000
# United Kingdom     193670000
# Germany            132440000
# France             110760000
# Southeast             770000
# Northeast             680000
# Central               480000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29999 entries, 0 to 20577
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29799 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  Int64
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductName         29999 non-null  object
#  11  ProductDescription  29999 non-null  object
#  12  ProductColor        16367 non-null  object
#  13  ProductSize         29999 non-null  object
#  14  ProductStyle        29999 non-null  object
# ...

# %%
df1['Name'].unique()
# Out:
# array(['MR. JOHN THOMAS', 'MR. BRANDON GARCIA', 'MR. ANGEL RICHARDSON',
#        ..., 'MS. MONICA RODRIGUEZ', 'MR. LUIS JENKINS',
#        'MR. MATTHEW JONES'], dtype=object)

# %%
df1['Name'].value_counts()
# Out:
# Name
# MR. CHARLES JACKSON      38
# MRS. SAMANTHA JENKINS    36
# MR. HENRY GARCIA         36
# MS. APRIL SHAN           34
# MR. MASON ROBERTS        33
#                          ..
# MR. KYLE PEREZ            1
# MR. JAMES WILLIAMS        1
# MR. GABRIEL FOSTER        1
# MRS. KARI GUTIERREZ       1
# MR. MATTHEW JONES         1
# Name: count, Length: 11373, dtype: int64

# %%
df1.pivot_table(index = 'Country',columns = 'Gender',values = 'AnnualIncome' , aggfunc='sum')
# Out:
# Gender                  F          M
# Country
# Australia       232660000  226240000
# Canada           98430000  122420000
# France           54250000   55500000
# Germany          68770000   61700000
# United Kingdom   99620000   92980000
# United States   342440000  340050000

# %%
df1.pivot_table(index = 'Occupation',columns = 'Gender',values = 'OrderQuantity',aggfunc = 'sum')
# Out:
# Gender             F     M
# Occupation
# Clerical        3183  3379
# Management      3755  4039
# Manual          2449  2593
# Professional    6939  6915
# Skilled Manual  5350  5326

# %%
df1['Gender'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
df1.isna().sum()
# Out:
# OrderDate                 0
# Name                      0
# BirthDate                 0
# Gender                  200
# EmailAddress              0
# AnnualIncome              0
# TotalChildren             0
# EducationLevel            0
# Occupation                0
# HomeOwner                 0
# ProductName               0
# ProductDescription        0
# ProductColor          13632
# ProductSize               0
# ProductStyle              0
# ProductPrice              0
# OrderQuantity             0
# SubcategoryName           0
# Region                    0
# Country                   0
# Continent                 0
# OrderYear                 0
# OrderMonth                0
# OrderMonthName            0
# dtype: int64

# %%
df1['Gender'].fillna('Not Defined',inplace=True)

# %%
df1.isna().sum()
# Out:
# OrderDate                 0
# Name                      0
# BirthDate                 0
# Gender                    0
# EmailAddress              0
# AnnualIncome              0
# TotalChildren             0
# EducationLevel            0
# Occupation                0
# HomeOwner                 0
# ProductName               0
# ProductDescription        0
# ProductColor          13632
# ProductSize               0
# ProductStyle              0
# ProductPrice              0
# OrderQuantity             0
# SubcategoryName           0
# Region                    0
# Country                   0
# Continent                 0
# OrderYear                 0
# OrderMonth                0
# OrderMonthName            0
# dtype: int64

# %%
df1['ProductColor'].fillna('No Color',inplace=True)

# %%
df1.isna().sum()
# Out:
# OrderDate             0
# Name                  0
# BirthDate             0
# Gender                0
# EmailAddress          0
# AnnualIncome          0
# TotalChildren         0
# EducationLevel        0
# Occupation            0
# HomeOwner             0
# ProductName           0
# ProductDescription    0
# ProductColor          0
# ProductSize           0
# ProductStyle          0
# ProductPrice          0
# OrderQuantity         0
# SubcategoryName       0
# Region                0
# Country               0
# Continent             0
# OrderYear             0
# OrderMonth            0
# OrderMonthName        0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29999 entries, 0 to 20577
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29999 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  Int64
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductName         29999 non-null  object
#  11  ProductDescription  29999 non-null  object
#  12  ProductColor        29999 non-null  object
#  13  ProductSize         29999 non-null  object
#  14  ProductStyle        29999 non-null  object
# ...

# %%
df1.pivot_table(index = 'Country',columns = 'OrderYear' , values = 'OrderQuantity' , aggfunc = 'sum')
# Out:
# OrderYear       2015   2016  2017
# Country
# Australia        848   7616  1185
# Canada           223   4811   783
# France           229   3397   414
# Germany          226   3338   515
# United Kingdom   255   4346   552
# United States    849  12722  1922

# %%
df1.pivot_table(index = 'Country',columns = 'OrderYear',values = 'OrderQuantity' , aggfunc = 'sum')
# Out:
# OrderYear       2015   2016  2017
# Country
# Australia        848   7616  1185
# Canada           223   4811   783
# France           229   3397   414
# Germany          226   3338   515
# United Kingdom   255   4346   552
# United States    849  12722  1922

# %%
df1.pivot_table(index ='Occupation',columns = 'Gender',values = 'OrderQuantity',aggfunc = 'sum').ascending=False

# %%
df1.pivot_table(index ='Occupation',columns = 'Gender',values = 'OrderQuantity',aggfunc = 'sum').ascending=False

# %%
df1.pivot_table(index='ProductName',columns='Gender',values='OrderQuantity',aggfunc='sum')
# Out:
# Gender                           F       M  Not Defined
# ProductName
# AWC Logo Cap                1003.0  1016.0         16.0
# All-Purpose Bike Stand        75.0    54.0          1.0
# Bike Wash - Dissolver        427.0   460.0         10.0
# Classic Vest, L               37.0    46.0          NaN
# Classic Vest, M               41.0    45.0          2.0
# ...                            ...     ...          ...
# Touring-3000 Yellow, 62        4.0    17.0          NaN
# Water Bottle - 30 oz.       1935.0  2000.0         15.0
# Women's Mountain Shorts, L    80.0    91.0          3.0
# Women's Mountain Shorts, M    79.0    94.0          NaN
# Women's Mountain Shorts, S    67.0    68.0          1.0
#
# [130 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29999 entries, 0 to 20577
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           29999 non-null  datetime64[ns]
#  1   Name                29999 non-null  object
#  2   BirthDate           29999 non-null  datetime64[ns]
#  3   Gender              29999 non-null  object
#  4   EmailAddress        29999 non-null  object
#  5   AnnualIncome        29999 non-null  Int64
#  6   TotalChildren       29999 non-null  int64
#  7   EducationLevel      29999 non-null  object
#  8   Occupation          29999 non-null  object
#  9   HomeOwner           29999 non-null  object
#  10  ProductName         29999 non-null  object
#  11  ProductDescription  29999 non-null  object
#  12  ProductColor        29999 non-null  object
#  13  ProductSize         29999 non-null  object
#  14  ProductStyle        29999 non-null  object
# ...

# %%
df1.pivot_table(index=['Occupation','ProductName'],columns='Gender',values='OrderQuantity',aggfunc='sum')
# Out:
# Gender                                         F      M  Not Defined
# Occupation     ProductName
# Clerical       AWC Logo Cap                142.0  178.0          NaN
#                All-Purpose Bike Stand       10.0    9.0          NaN
#                Bike Wash - Dissolver        57.0   57.0          2.0
#                Classic Vest, L               4.0    9.0          NaN
#                Classic Vest, M               9.0    6.0          1.0
# ...                                          ...    ...          ...
# Skilled Manual Touring-3000 Yellow, 62       2.0    4.0          NaN
#                Water Bottle - 30 oz.       543.0  519.0          2.0
#                Women's Mountain Shorts, L   26.0   28.0          NaN
#                Women's Mountain Shorts, M   24.0   25.0          NaN
#                Women's Mountain Shorts, S   24.0   25.0          1.0
#
# [647 rows x 3 columns]

# %%
import pandas as pd
df2=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/cases_deaths_eu.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33910 entries, 0 to 33909
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       33910 non-null  object
#  1   country_code  32780 non-null  object
#  2   continent     33910 non-null  object
#  3   population    33910 non-null  int64
#  4   indicator     33910 non-null  object
#  5   daily_count   33910 non-null  int64
#  6   date          33910 non-null  object
#  7   rate_14_day   32428 non-null  float64
#  8   source        33910 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.3+ MB

# %%
df2.isna().sum()
# Out:
# country            0
# country_code    1130
# continent          0
# population         0
# indicator          0
# daily_count        0
# date               0
# rate_14_day     1482
# source             0
# dtype: int64

# %%
df2['rate_14_day'].mean()
# Out:
# 30.661950584342144

# %%
df2['rate_14_day'].max()
# Out:
# 1761.686598

# %%
df2['rate_14_day'].fillna(df2['rate_14_day'].mean(),inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33910 entries, 0 to 33909
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       33910 non-null  object
#  1   country_code  32780 non-null  object
#  2   continent     33910 non-null  object
#  3   population    33910 non-null  int64
#  4   indicator     33910 non-null  object
#  5   daily_count   33910 non-null  int64
#  6   date          33910 non-null  object
#  7   rate_14_day   33910 non-null  float64
#  8   source        33910 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.3+ MB

# %%
df2
# Out:
#               country country_code continent  population        indicator  \
# 0             Albania          ALB    Europe     2862427  confirmed cases
# 1             Albania          ALB    Europe     2862427  confirmed cases
# 2             Albania          ALB    Europe     2862427  confirmed cases
# 3             Albania          ALB    Europe     2862427  confirmed cases
# 4             Albania          ALB    Europe     2862427  confirmed cases
# ...               ...          ...       ...         ...              ...
# 33905  United Kingdom          GBR    Europe    66647112           deaths
# 33906  United Kingdom          GBR    Europe    66647112           deaths
# 33907  United Kingdom          GBR    Europe    66647112           deaths
# 33908  United Kingdom          GBR    Europe    66647112           deaths
# 33909  United Kingdom          GBR    Europe    66647112           deaths
#
#        daily_count        date  rate_14_day  \
# ...

# %%
df2['date'].astype('datetime64[ns]')
# Out:
# 0       2020-01-02
# 1       2020-01-03
# 2       2020-01-04
# 3       2020-01-05
# 4       2020-01-06
#            ...
# 33905   2020-10-21
# 33906   2020-10-22
# 33907   2020-10-23
# 33908   2020-10-24
# 33909   2020-10-25
# Name: date, Length: 33910, dtype: datetime64[ns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33910 entries, 0 to 33909
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       33910 non-null  object
#  1   country_code  32780 non-null  object
#  2   continent     33910 non-null  object
#  3   population    33910 non-null  int64
#  4   indicator     33910 non-null  object
#  5   daily_count   33910 non-null  int64
#  6   date          33910 non-null  object
#  7   rate_14_day   33910 non-null  float64
#  8   source        33910 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.3+ MB

# %%
df2['date'] = df2['date'].astype('datetime64[ns]')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33910 entries, 0 to 33909
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       33910 non-null  object
#  1   country_code  32780 non-null  object
#  2   continent     33910 non-null  object
#  3   population    33910 non-null  int64
#  4   indicator     33910 non-null  object
#  5   daily_count   33910 non-null  int64
#  6   date          33910 non-null  datetime64[ns]
#  7   rate_14_day   33910 non-null  float64
#  8   source        33910 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 2.3+ MB

# %%
df2['year'] = df2['date'].dt.year

# %%
df2['month'] = df2['date'].dt.month

# %%
df2['month_name'] = df2['date'].dt.month_name()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33910 entries, 0 to 33909
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       33910 non-null  object
#  1   country_code  32780 non-null  object
#  2   continent     33910 non-null  object
#  3   population    33910 non-null  int64
#  4   indicator     33910 non-null  object
#  5   daily_count   33910 non-null  int64
#  6   date          33910 non-null  datetime64[ns]
#  7   rate_14_day   33910 non-null  float64
#  8   source        33910 non-null  object
#  9   year          33910 non-null  int32
#  10  month         33910 non-null  int32
#  11  month_name    33910 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(2), object(6)
# memory usage: 2.8+ MB

# %%
df2.pivot_table(index = 'country',columns =['year','source'] , values ='population' ,aggfunc = 'sum')
# Out:
# year                                                                   2020
# source                           Epidemic intelligence, national daily data
# country
# Albania                                                          1706006492
# Andorra                                                            45401492
# Armenia                                                          1766087464
# Austria                                                          5279829900
# Azerbaijan                                                       6042948300
# Belarus                                                          5631795316
# Belgium                                                          6827489324
# Bosnia and Herzegovina                                           1955365740
# Bulgaria                                                         4172023244
# Croatia                                                          2429442616
# ...
