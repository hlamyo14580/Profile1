# %% [markdown]
# <a href="https://colab.research.google.com/github/hlamyo14580/Profile1/blob/main/AWPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
sale_2015 = pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/aw_Sales_2015.csv')
sale_2016 = pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/aw_Sales_2016.csv')
sale_2017 = pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/aw_Sales_2017.csv')

# %%
sale_2015.head(10)
# Out:
#   OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0  1/1/2015   9/21/2001     SO45080         332        14657             1
# 1  1/1/2015   12/5/2001     SO45079         312        29255             4
# 2  1/1/2015  10/29/2001     SO45082         350        11455             9
# 3  1/1/2015  11/16/2001     SO45081         338        26782             6
# 4  1/2/2015  12/15/2001     SO45083         312        14947            10
# 5  1/2/2015  10/12/2001     SO45084         310        29143             4
# 6  1/2/2015  12/18/2001     SO45086         314        18747             9
# 7  1/2/2015   10/9/2001     SO45085         312        18746             9
# 8  1/3/2015   10/3/2001     SO45093         312        18906             9
# 9  1/3/2015   9/29/2001     SO45090         310        29170             4
#
#    OrderLineItem  OrderQuantity
# 0              1              1
# 1              1              1
# 2              1              1
# ...

# %%
sale_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderDate      2630 non-null   object
#  1   StockDate      2630 non-null   object
#  2   OrderNumber    2630 non-null   object
#  3   ProductKey     2630 non-null   int64
#  4   CustomerKey    2630 non-null   int64
#  5   TerritoryKey   2630 non-null   int64
#  6   OrderLineItem  2630 non-null   int64
#  7   OrderQuantity  2630 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 164.5+ KB

# %%
sale_2015.describe()
# Out:
#         ProductKey   CustomerKey  TerritoryKey  OrderLineItem  OrderQuantity
# count  2630.000000   2630.000000   2630.000000         2630.0         2630.0
# mean    344.180608  18344.052471      6.587833            1.0            1.0
# std      26.288429   5567.047291      2.915261            0.0            0.0
# min     310.000000  11090.000000      1.000000            1.0            1.0
# 25%     314.000000  13118.250000      4.000000            1.0            1.0
# 50%     348.000000  16828.500000      8.000000            1.0            1.0
# 75%     370.000000  22859.250000      9.000000            1.0            1.0
# max     389.000000  29481.000000     10.000000            1.0            1.0

# %%
sale_2015['OrderDate'].astype('datetime64[ns]')
# Out:
# 0      2015-01-01
# 1      2015-01-01
# 2      2015-01-01
# 3      2015-01-01
# 4      2015-01-02
#           ...
# 2625   2015-12-31
# 2626   2015-12-31
# 2627   2015-12-31
# 2628   2015-12-31
# 2629   2015-12-31
# Name: OrderDate, Length: 2630, dtype: datetime64[ns]

# %%
sale_2015['OrderDate'] = sale_2015['OrderDate'].astype('datetime64[ns]')

# %%
sale_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderDate      2630 non-null   datetime64[ns]
#  1   StockDate      2630 non-null   object
#  2   OrderNumber    2630 non-null   object
#  3   ProductKey     2630 non-null   int64
#  4   CustomerKey    2630 non-null   int64
#  5   TerritoryKey   2630 non-null   int64
#  6   OrderLineItem  2630 non-null   int64
#  7   OrderQuantity  2630 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(2)
# memory usage: 164.5+ KB

# %%
sale_2015['StockDate'] = sale_2015['StockDate'].astype('datetime64[ns]')

# %%
sale_2016['OrderDate'] = sale_2016['OrderDate'].astype('datetime64[ns]')

# %%
sale_2016['StockDate'] = sale_2016['StockDate'].astype('datetime64[ns]')

# %%
sale_2017['OrderDate'] = sale_2017['OrderDate'].astype('datetime64[ns]')

# %%
sale_2017['StockDate'] = sale_2017['StockDate'].astype('datetime64[ns]')

# %%
sale_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23935 entries, 0 to 23934
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderDate      23935 non-null  datetime64[ns]
#  1   StockDate      23935 non-null  datetime64[ns]
#  2   OrderNumber    23935 non-null  object
#  3   ProductKey     23935 non-null  int64
#  4   CustomerKey    23935 non-null  int64
#  5   TerritoryKey   23935 non-null  int64
#  6   OrderLineItem  23935 non-null  int64
#  7   OrderQuantity  23935 non-null  int64
# dtypes: datetime64[ns](2), int64(5), object(1)
# memory usage: 1.5+ MB

# %%
sale_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29481 entries, 0 to 29480
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderDate      29481 non-null  datetime64[ns]
#  1   StockDate      29481 non-null  datetime64[ns]
#  2   OrderNumber    29481 non-null  object
#  3   ProductKey     29481 non-null  int64
#  4   CustomerKey    29481 non-null  int64
#  5   TerritoryKey   29481 non-null  int64
#  6   OrderLineItem  29481 non-null  int64
#  7   OrderQuantity  29481 non-null  int64
# dtypes: datetime64[ns](2), int64(5), object(1)
# memory usage: 1.8+ MB

# %%
pd.concat([sale_2015,sale_2016,sale_2017])
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2015-01-01 2001-09-21     SO45080         332        14657
# 1     2015-01-01 2001-12-05     SO45079         312        29255
# 2     2015-01-01 2001-10-29     SO45082         350        11455
# 3     2015-01-01 2001-11-16     SO45081         338        26782
# 4     2015-01-02 2001-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 29476 2017-12-30 2004-03-22     SO74143         477        28517
# 29477 2017-12-30 2004-03-15     SO74143         479        28517
# 29478 2017-12-30 2004-04-08     SO74143         606        28517
# 29479 2017-12-30 2004-05-15     SO74124         480        21676
# 29480 2017-12-30 2004-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity
# 0                 1              1              1
# 1                 4              1              1
# ...

# %%
sales=pd.concat([sale_2015,sale_2016,sale_2017])

# %%
sales
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2015-01-01 2001-09-21     SO45080         332        14657
# 1     2015-01-01 2001-12-05     SO45079         312        29255
# 2     2015-01-01 2001-10-29     SO45082         350        11455
# 3     2015-01-01 2001-11-16     SO45081         338        26782
# 4     2015-01-02 2001-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 29476 2017-12-30 2004-03-22     SO74143         477        28517
# 29477 2017-12-30 2004-03-15     SO74143         479        28517
# 29478 2017-12-30 2004-04-08     SO74143         606        28517
# 29479 2017-12-30 2004-05-15     SO74124         480        21676
# 29480 2017-12-30 2004-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity
# 0                 1              1              1
# 1                 4              1              1
# ...

# %%
sales['ProductKey'].value_counts()
# Out:
# ProductKey
# 477    3983
# 480    2952
# 528    2846
# 529    2173
# 214    2099
#        ...
# 349      26
# 348      26
# 345      25
# 346      24
# 347      22
# Name: count, Length: 130, dtype: int64

# %%
products = pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/aw_Products.csv')

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             293 non-null    int64
#  1   ProductSubcategoryKey  293 non-null    int64
#  2   ProductSKU             293 non-null    object
#  3   ProductName            293 non-null    object
#  4   ModelName              293 non-null    object
#  5   ProductDescription     293 non-null    object
#  6   ProductColor           243 non-null    object
#  7   ProductSize            293 non-null    object
#  8   ProductStyle           293 non-null    object
#  9   ProductCost            293 non-null    float64
#  10  ProductPrice           293 non-null    float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 25.3+ KB

# %%
products['ProductKey'].value_counts()
# Out:
# ProductKey
# 214    1
# 498    1
# 514    1
# 513    1
# 512    1
#       ..
# 393    1
# 392    1
# 391    1
# 389    1
# 606    1
# Name: count, Length: 293, dtype: int64

# %%
products
# Out:
#      ProductKey  ProductSubcategoryKey  ProductSKU              ProductName  \
# 0           214                     31   HL-U509-R    Sport-100 Helmet, Red
# 1           215                     31     HL-U509  Sport-100 Helmet, Black
# 2           218                     23   SO-B909-M   Mountain Bike Socks, M
# 3           219                     23   SO-B909-L   Mountain Bike Socks, L
# 4           220                     31   HL-U509-B   Sport-100 Helmet, Blue
# ..          ...                    ...         ...                      ...
# 288         602                      5     BB-8107        ML Bottom Bracket
# 289         603                      5     BB-9108        HL Bottom Bracket
# 290         604                      2  BK-R19B-44       Road-750 Black, 44
# 291         605                      2  BK-R19B-48       Road-750 Black, 48
# 292         606                      2  BK-R19B-52       Road-750 Black, 52
#
# ...

# %%
sales.join(products.set_index('ProductKey'),on ='ProductKey')
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2015-01-01 2001-09-21     SO45080         332        14657
# 1     2015-01-01 2001-12-05     SO45079         312        29255
# 2     2015-01-01 2001-10-29     SO45082         350        11455
# 3     2015-01-01 2001-11-16     SO45081         338        26782
# 4     2015-01-02 2001-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 29476 2017-12-30 2004-03-22     SO74143         477        28517
# 29477 2017-12-30 2004-03-15     SO74143         479        28517
# 29478 2017-12-30 2004-04-08     SO74143         606        28517
# 29479 2017-12-30 2004-05-15     SO74124         480        21676
# 29480 2017-12-30 2004-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity  ProductSubcategoryKey  \
# 0                 1              1              1                      2
# ...

# %%
products.columns
# Out:
# Index(['ProductKey', 'ProductSubcategoryKey', 'ProductSKU', 'ProductName',
#        'ModelName', 'ProductDescription', 'ProductColor', 'ProductSize',
#        'ProductStyle', 'ProductCost', 'ProductPrice'],
#       dtype='object')

# %%
sales.columns
# Out:
# Index(['OrderDate', 'StockDate', 'OrderNumber', 'ProductKey', 'CustomerKey',
#        'TerritoryKey', 'OrderLineItem', 'OrderQuantity'],
#       dtype='object')

# %%
products[['ProductKey','ProductSubcategoryKey','ProductName','ProductCost','ProductPrice']].set_index('ProductKey')
# Out:
#             ProductSubcategoryKey              ProductName  ProductCost  \
# ProductKey
# 214                            31    Sport-100 Helmet, Red      13.0863
# 215                            31  Sport-100 Helmet, Black      12.0278
# 218                            23   Mountain Bike Socks, M       3.3963
# 219                            23   Mountain Bike Socks, L       3.3963
# 220                            31   Sport-100 Helmet, Blue      12.0278
# ...                           ...                      ...          ...
# 602                             5        ML Bottom Bracket      44.9506
# 603                             5        HL Bottom Bracket      53.9416
# 604                             2       Road-750 Black, 44     343.6496
# 605                             2       Road-750 Black, 48     343.6496
# 606                             2       Road-750 Black, 52     343.6496
#
#             ProductPrice
# ProductKey
# 214              34.9900
# 215              33.6442
# ...

# %%
sales.join(products[['ProductKey','ProductSubcategoryKey','ProductName','ProductCost','ProductPrice']].set_index('ProductKey'),on='ProductKey')
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2015-01-01 2001-09-21     SO45080         332        14657
# 1     2015-01-01 2001-12-05     SO45079         312        29255
# 2     2015-01-01 2001-10-29     SO45082         350        11455
# 3     2015-01-01 2001-11-16     SO45081         338        26782
# 4     2015-01-02 2001-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 29476 2017-12-30 2004-03-22     SO74143         477        28517
# 29477 2017-12-30 2004-03-15     SO74143         479        28517
# 29478 2017-12-30 2004-04-08     SO74143         606        28517
# 29479 2017-12-30 2004-05-15     SO74124         480        21676
# 29480 2017-12-30 2004-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity  ProductSubcategoryKey  \
# 0                 1              1              1                      2
# ...

# %%
sales=sales.join(products[['ProductKey','ProductSubcategoryKey','ProductName','ProductCost','ProductPrice']].set_index('ProductKey'),on='ProductKey')

# %%
sales
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2015-01-01 2001-09-21     SO45080         332        14657
# 1     2015-01-01 2001-12-05     SO45079         312        29255
# 2     2015-01-01 2001-10-29     SO45082         350        11455
# 3     2015-01-01 2001-11-16     SO45081         338        26782
# 4     2015-01-02 2001-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 29476 2017-12-30 2004-03-22     SO74143         477        28517
# 29477 2017-12-30 2004-03-15     SO74143         479        28517
# 29478 2017-12-30 2004-04-08     SO74143         606        28517
# 29479 2017-12-30 2004-05-15     SO74124         480        21676
# 29480 2017-12-30 2004-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity  ProductSubcategoryKey  \
# 0                 1              1              1                      2
# ...

# %%
regions = pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/aw_Territories.csv')
regions
# Out:
#    SalesTerritoryKey          Region         Country      Continent
# 0                  1       Northwest   United States  North America
# 1                  2       Northeast   United States  North America
# 2                  3         Central   United States  North America
# 3                  4       Southwest   United States  North America
# 4                  5       Southeast   United States  North America
# 5                  6          Canada          Canada  North America
# 6                  7          France          France         Europe
# 7                  8         Germany         Germany         Europe
# 8                  9       Australia       Australia        Pacific
# 9                 10  United Kingdom  United Kingdom         Europe

# %%
regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesTerritoryKey  10 non-null     int64
#  1   Region             10 non-null     object
#  2   Country            10 non-null     object
#  3   Continent          10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 448.0+ bytes

# %%
sales.columns
# Out:
# Index(['OrderDate', 'StockDate', 'OrderNumber', 'ProductKey', 'CustomerKey',
#        'TerritoryKey', 'OrderLineItem', 'OrderQuantity',
#        'ProductSubcategoryKey', 'ProductName', 'ProductCost', 'ProductPrice'],
#       dtype='object')

# %%
sales.join(regions.set_index('SalesTerritoryKey'),on='TerritoryKey')
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2015-01-01 2001-09-21     SO45080         332        14657
# 1     2015-01-01 2001-12-05     SO45079         312        29255
# 2     2015-01-01 2001-10-29     SO45082         350        11455
# 3     2015-01-01 2001-11-16     SO45081         338        26782
# 4     2015-01-02 2001-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 29476 2017-12-30 2004-03-22     SO74143         477        28517
# 29477 2017-12-30 2004-03-15     SO74143         479        28517
# 29478 2017-12-30 2004-04-08     SO74143         606        28517
# 29479 2017-12-30 2004-05-15     SO74124         480        21676
# 29480 2017-12-30 2004-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity  ProductSubcategoryKey  \
# 0                 1              1              1                      2
# ...

# %%
sales = sales.join(regions.set_index('SalesTerritoryKey'),on='TerritoryKey')

# %%
customers = pd.read_csv('https://github.com/KaungAlex/pandas/raw/main/aw_Customers.csv',encoding='latin')
customers
# Out:
#        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG    4/8/1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES   8/12/1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON    8/8/1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG    7/4/1958             M
# 18144        29480   MRS.       NINA     RAJI  11/10/1960             S
# 18145        29481    MR.       IVAN     SURI    1/5/1960             S
# 18146        29482    MR.    CLAYTON    ZHANG    3/5/1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO   12/8/1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Prefix          18018 non-null  object
#  2   FirstName       18148 non-null  object
#  3   LastName        18148 non-null  object
#  4   BirthDate       18148 non-null  object
#  5   MaritalStatus   18148 non-null  object
#  6   Gender          18018 non-null  object
#  7   EmailAddress    18148 non-null  object
#  8   AnnualIncome    18148 non-null  object
#  9   TotalChildren   18148 non-null  int64
#  10  EducationLevel  18148 non-null  object
#  11  Occupation      18148 non-null  object
#  12  HomeOwner       18148 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 1.8+ MB

# %%
customers.columns
# Out:
# Index(['CustomerKey', 'Prefix', 'FirstName', 'LastName', 'BirthDate',
#        'MaritalStatus', 'Gender', 'EmailAddress', 'AnnualIncome',
#        'TotalChildren', 'EducationLevel', 'Occupation', 'HomeOwner'],
#       dtype='object')

# %%
customers['Prefix']+' '+customers['FirstName']+' '+customers['LastName']
# Out:
# 0                  MR. JON YANG
# 1              MR. EUGENE HUANG
# 2              MR. RUBEN TORRES
# 3               MS. CHRISTY ZHU
# 4        MRS. ELIZABETH JOHNSON
#                   ...
# 18143            MR. TOMMY TANG
# 18144            MRS. NINA RAJI
# 18145             MR. IVAN SURI
# 18146         MR. CLAYTON ZHANG
# 18147         MR. JÉSUS NAVARRO
# Length: 18148, dtype: object

# %%
customers['Name'] = customers['Prefix']+' '+customers['FirstName']+' '+customers['LastName']

# %%
customers['Name']
# Out:
# 0                  MR. JON YANG
# 1              MR. EUGENE HUANG
# 2              MR. RUBEN TORRES
# 3               MS. CHRISTY ZHU
# 4        MRS. ELIZABETH JOHNSON
#                   ...
# 18143            MR. TOMMY TANG
# 18144            MRS. NINA RAJI
# 18145             MR. IVAN SURI
# 18146         MR. CLAYTON ZHANG
# 18147         MR. JÉSUS NAVARRO
# Name: Name, Length: 18148, dtype: object

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Prefix          18018 non-null  object
#  2   FirstName       18148 non-null  object
#  3   LastName        18148 non-null  object
#  4   BirthDate       18148 non-null  object
#  5   MaritalStatus   18148 non-null  object
#  6   Gender          18018 non-null  object
#  7   EmailAddress    18148 non-null  object
#  8   AnnualIncome    18148 non-null  object
#  9   TotalChildren   18148 non-null  int64
#  10  EducationLevel  18148 non-null  object
#  11  Occupation      18148 non-null  object
#  12  HomeOwner       18148 non-null  object
#  13  Name            18018 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 1.9+ MB

# %%
customers.columns
# Out:
# Index(['CustomerKey', 'Prefix', 'FirstName', 'LastName', 'BirthDate',
#        'MaritalStatus', 'Gender', 'EmailAddress', 'AnnualIncome',
#        'TotalChildren', 'EducationLevel', 'Occupation', 'HomeOwner', 'Name'],
#       dtype='object')

# %%
customers
# Out:
#        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG    4/8/1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES   8/12/1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON    8/8/1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG    7/4/1958             M
# 18144        29480   MRS.       NINA     RAJI  11/10/1960             S
# 18145        29481    MR.       IVAN     SURI    1/5/1960             S
# 18146        29482    MR.    CLAYTON    ZHANG    3/5/1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO   12/8/1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
sales.join(customers.set_index('CustomerKey'),on='CustomerKey')
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2015-01-01 2001-09-21     SO45080         332        14657
# 1     2015-01-01 2001-12-05     SO45079         312        29255
# 2     2015-01-01 2001-10-29     SO45082         350        11455
# 3     2015-01-01 2001-11-16     SO45081         338        26782
# 4     2015-01-02 2001-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 29476 2017-12-30 2004-03-22     SO74143         477        28517
# 29477 2017-12-30 2004-03-15     SO74143         479        28517
# 29478 2017-12-30 2004-04-08     SO74143         606        28517
# 29479 2017-12-30 2004-05-15     SO74124         480        21676
# 29480 2017-12-30 2004-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity  ProductSubcategoryKey  \
# 0                 1              1              1                      2
# ...

# %%
sales = sales.join(customers.set_index('CustomerKey'),on='CustomerKey')

# %%
sales
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2015-01-01 2001-09-21     SO45080         332        14657
# 1     2015-01-01 2001-12-05     SO45079         312        29255
# 2     2015-01-01 2001-10-29     SO45082         350        11455
# 3     2015-01-01 2001-11-16     SO45081         338        26782
# 4     2015-01-02 2001-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 29476 2017-12-30 2004-03-22     SO74143         477        28517
# 29477 2017-12-30 2004-03-15     SO74143         479        28517
# 29478 2017-12-30 2004-04-08     SO74143         606        28517
# 29479 2017-12-30 2004-05-15     SO74124         480        21676
# 29480 2017-12-30 2004-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity  ProductSubcategoryKey  \
# 0                 1              1              1                      2
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
def split_replace(x):
  x = x.split('$')[1]
  x = x.replace(',','')
  x = int(x)
  return(x)

# %%
sales['AnnualIncome']=sales['AnnualIncome'].apply(split_replace)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales['BirthDate']=pd.to_datetime(sales['BirthDate'])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales.isna().sum()
# Out:
# OrderDate                  0
# StockDate                  0
# OrderNumber                0
# ProductKey                 0
# CustomerKey                0
# TerritoryKey               0
# OrderLineItem              0
# OrderQuantity              0
# ProductSubcategoryKey      0
# ProductName                0
# ProductCost                0
# ProductPrice               0
# Region                     0
# Country                    0
# Continent                  0
# Prefix                   380
# FirstName                  0
# LastName                   0
# BirthDate                  0
# MaritalStatus              0
# Gender                   380
# EmailAddress               0
# AnnualIncome               0
# TotalChildren              0
# EducationLevel             0
# Occupation                 0
# HomeOwner                  0
# Name                     380
# dtype: int64

# %%
sales['Prefix'].unique()
# Out:
# array(['MR.', 'MRS.', 'MS.', nan], dtype=object)

# %%
sales['Gender'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
sales['Gender'].fillna('Not_Defined',inplace=True)

# %%
sales['Name'].unique()
# Out:
# array(['MR. JOHN THOMAS', 'MR. KYLE WASHINGTON', 'MR. ROSS SANZ', ...,
#        'MRS. STEPHANIE REED', 'MR. TROY GONZALEZ', 'MS. VALERIE GUO'],
#       dtype=object)

# %%
sales['Name'].value_counts()
# Out:
# Name
# MR. FERNANDO BARNES      64
# MRS. ASHLEY HENDERSON    61
# MRS. JENNIFER SIMMONS    59
# MR. CHARLES JACKSON      57
# MR. DALTON PEREZ         56
#                          ..
# MR. CORY CHANDRA          1
# MR. JAY SERRANO           1
# MR. ADRIAN JAMES          1
# MR. EVAN ADAMS            1
# MR. RAFAEL SHAN           1
# Name: count, Length: 17259, dtype: int64

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales['Sales_Amt']=sales['OrderQuantity']*sales['ProductPrice']

# %%
sales['Cost_Amt']=sales['OrderQuantity']*sales['ProductCost']

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales.drop(columns=['Prefix','FirstName','LastName'],inplace=True)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales['Gross Profit']=sales['Sales_Amt']-sales['Cost_Amt']

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales[['ProductName','Sales_Amt']].groupby(by='ProductName').sum().sort_values(by='Sales_Amt',ascending=False)
# Out:
#                             Sales_Amt
# ProductName
# Mountain-200 Black, 46   1.241754e+06
# Mountain-200 Black, 42   1.233557e+06
# Mountain-200 Silver, 38  1.213852e+06
# Mountain-200 Silver, 46  1.182781e+06
# Mountain-200 Black, 38   1.165937e+06
# ...                               ...
# Classic Vest, M          1.155700e+04
# Classic Vest, L          1.155700e+04
# Classic Vest, S          9.969500e+03
# Racing Socks, M          4.980460e+03
# Racing Socks, L          4.575910e+03
#
# [130 rows x 1 columns]

# %%
sales['Order_Year']=sales['OrderDate'].dt.year

# %%
sales['Order_Month']=sales['OrderDate'].dt.month

# %%
sales['Order_Month_Name']=sales['OrderDate'].dt.month_name()

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales[['Order_Year','ProductName','Sales_Amt']].groupby(by='Order_Year').sum().sort_values(by='Sales_Amt',ascending=True)
#
# Out:
#                                                   ProductName     Sales_Amt
# Order_Year
# 2015        Road-650 Black, 58Road-150 Red, 48Mountain-100...  6.404934e+06
# 2017        Road Tire TubeSport-100 Helmet, RedHL Road Tir...  9.185449e+06
# 2016        Road-550-W Yellow, 42Road-550-W Yellow, 40Road...  9.324204e+06

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales[['Region','ProductName','Gross Profit']].groupby(by='ProductName').sum().sort_values(by='Gross Profit',ascending=False)
# Out:
#                                                                             Region  \
# ProductName
# Mountain-200 Black, 46           AustraliaUnited KingdomAustraliaAustraliaSouth...
# Mountain-200 Black, 42           AustraliaAustraliaSouthwestNorthwestSouthwestA...
# Mountain-200 Silver, 38          CanadaUnited KingdomFranceCanadaSouthwestUnite...
# Mountain-200 Silver, 46          GermanyUnited KingdomSouthwestSouthwestSouthwe...
# Mountain-200 Black, 38           AustraliaCanadaAustraliaCanadaAustraliaAustral...
# ...                                                                            ...
# Short-Sleeve Classic Jersey, XL  FranceAustraliaGermanyAustraliaAustraliaCanada...
# Short-Sleeve Classic Jersey, M   GermanyUnited KingdomAustraliaFranceUnited Kin...
# Short-Sleeve Classic Jersey, L   GermanyUnited KingdomFranceNorthwestSouthwestA...
# Racing Socks, M                  AustraliaAustraliaNorthwestSouthwestSouthwestN...
# ...

# %%
sales.pivot_table(index='Occupation',columns='Gender',values='AnnualIncome',aggfunc='sum').sort_values(by='Occupation',ascending=False)
# Out:
# Gender                  F          M  Not_Defined
# Occupation
# Skilled Manual  345420000  337980000      4200000
# Professional    682680000  663160000      8100000
# Manual           49850000   56750000      1000000
# Management      435040000  481080000      5200000
# Clerical        136870000  139430000      2610000

# %%
sales[['Order_Year','Gross Profit']].groupby(by='Order_Year').sum()
# Out:
#             Gross Profit
# Order_Year
# 2015        2.601602e+06
# 2016        3.967084e+06
# 2017        3.889029e+06

# %%
sales[sales['Order_Year']== 2015]
# Out:
#       OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0    2015-01-01 2001-09-21     SO45080         332        14657             1
# 1    2015-01-01 2001-12-05     SO45079         312        29255             4
# 2    2015-01-01 2001-10-29     SO45082         350        11455             9
# 3    2015-01-01 2001-11-16     SO45081         338        26782             6
# 4    2015-01-02 2001-12-15     SO45083         312        14947            10
# ...         ...        ...         ...         ...          ...           ...
# 2625 2015-12-31 2002-11-29     SO48728         354        13111             9
# 2626 2015-12-31 2002-11-14     SO48729         324        26563             9
# 2627 2015-12-31 2002-12-02     SO48724         340        20722             8
# 2628 2015-12-31 2002-10-09     SO48723         369        14944             7
# 2629 2015-12-31 2002-11-22     SO48726         383        24915             9
#
# ...

# %%
sales['Order_Year'].value_counts().sort_values(ascending=True)
# Out:
# Order_Year
# 2015     2630
# 2016    23935
# 2017    29481
# Name: count, dtype: int64

# %%
import seaborn as sb
sb.barplot(data=sales,x='Order_Year',y='Sales_Amt')
# Out:
# <Axes: xlabel='Order_Year', ylabel='Sales_Amt'>

# %%
sb.lineplot(data=sales,x='Order_Month_Name',y='Sales_Amt').plot(figsize=(20,20))
# Out:
# []

# %%
productsubcategories = pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/aw_Product_Subcategories.csv')
productsubcategories
# Out:
#     ProductSubcategoryKey    SubcategoryName  ProductCategoryKey
# 0                       1     Mountain Bikes                   1
# 1                       2         Road Bikes                   1
# 2                       3      Touring Bikes                   1
# 3                       4         Handlebars                   2
# 4                       5    Bottom Brackets                   2
# 5                       6             Brakes                   2
# 6                       7             Chains                   2
# 7                       8          Cranksets                   2
# 8                       9        Derailleurs                   2
# 9                      10              Forks                   2
# 10                     11           Headsets                   2
# 11                     12    Mountain Frames                   2
# 12                     13             Pedals                   2
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
productsubcategories.columns
# Out:
# Index(['ProductSubcategoryKey', 'SubcategoryName', 'ProductCategoryKey'], dtype='object')

# %%
sales.columns
# Out:
# Index(['OrderDate', 'StockDate', 'OrderNumber', 'ProductKey', 'CustomerKey',
#        'TerritoryKey', 'OrderLineItem', 'OrderQuantity',
#        'ProductSubcategoryKey', 'ProductName', 'ProductCost', 'ProductPrice',
#        'Region', 'Country', 'Continent', 'BirthDate', 'MaritalStatus',
#        'Gender', 'EmailAddress', 'AnnualIncome', 'TotalChildren',
#        'EducationLevel', 'Occupation', 'HomeOwner', 'Name', 'Sales_Amt',
#        'Cost_Amt', 'Gross Profit', 'Order_Year', 'Order_Month',
#        'Order_Month_Name'],
#       dtype='object')

# %%
sales=sales.join(productsubcategories.set_index('ProductSubcategoryKey'),on='ProductSubcategoryKey')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales[['Order_Year','SubcategoryName','Sales_Amt']].groupby(by='SubcategoryName').sum().sort_values(by='Sales_Amt',ascending=False)
# Out:
#                    Order_Year     Sales_Amt
# SubcategoryName
# Road Bikes           14311881  1.128718e+07
# Mountain Bikes        9488745  8.583748e+06
# Touring Bikes         4283297  3.771565e+06
# Tires and Tubes      32204378  3.808267e+05
# Helmets              12167988  2.058339e+05
# Jerseys               6277594  1.585649e+05
# Bottles and Cages    15219109  1.077449e+05
# Fenders               3982710  8.704080e+04
# Shorts                1903620  6.607056e+04
# Gloves                2686082  6.226118e+04
# Hydration Packs       1401514  3.821805e+04
# Bike Stands            471860  3.720600e+04
# Bike Racks             608999  3.624000e+04
# Caps                  4158184  3.588207e+04
# Vests                 1050653  3.308350e+04
# Cleaners              1714074  1.356270e+04
# Socks                 1084899  9.556370e+03

# %%
sales.pivot_table(index='SubcategoryName',columns='Order_Year',values='Gross Profit',aggfunc='sum').sort_values(by='SubcategoryName',ascending=False)
# Out:
# Order_Year                 2015          2016          2017
# SubcategoryName
# Vests                       NaN  8.109204e+03  1.260107e+04
# Touring Bikes               NaN  5.283397e+05  8.988203e+05
# Tires and Tubes             NaN  1.062096e+05  1.321868e+05
# Socks                       NaN  2.718179e+03  3.264066e+03
# Shorts                      NaN  1.875226e+04  2.260787e+04
# Road Bikes         1.913016e+06  1.429116e+06  1.026214e+06
# Mountain Bikes     6.885858e+05  1.689565e+06  1.552511e+06
# Jerseys                     NaN  1.909640e+04  2.585985e+04
# Hydration Packs             NaN  1.036153e+04  1.356294e+04
# Helmets                     NaN  5.623959e+04  7.479681e+04
# Gloves                      NaN  1.528712e+04  2.129130e+04
# Fenders                     NaN  2.391401e+04  3.057361e+04
# Cleaners                    NaN  3.767362e+03  4.722888e+03
# Caps                        NaN  5.163823e+03  7.035966e+03
# ...

# %%
sales[sales['Order_Year']==2015].value_counts()
# Out:
# OrderDate   StockDate   OrderNumber  ProductKey  CustomerKey  TerritoryKey  OrderLineItem  OrderQuantity  ProductSubcategoryKey  ProductName              ProductCost  ProductPrice  Region     Country        Continent      BirthDate   MaritalStatus  Gender  EmailAddress                   AnnualIncome  TotalChildren  EducationLevel       Occupation      HomeOwner  Name                  Sales_Amt  Cost_Amt   Gross Profit  Order_Year  Order_Month  Order_Month_Name  SubcategoryName  ProductCategoryKey
# ...

# %%
sales[sales['Order_Year']==2015].isna().sum()
# Out:
# OrderDate                 0
# StockDate                 0
# OrderNumber               0
# ProductKey                0
# CustomerKey               0
# TerritoryKey              0
# OrderLineItem             0
# OrderQuantity             0
# ProductSubcategoryKey     0
# ProductName               0
# ProductCost               0
# ProductPrice              0
# Region                    0
# Country                   0
# Continent                 0
# BirthDate                 0
# MaritalStatus             0
# Gender                    0
# EmailAddress              0
# AnnualIncome              0
# TotalChildren             0
# EducationLevel            0
# Occupation                0
# HomeOwner                 0
# Name                     11
# Sales_Amt                 0
# Cost_Amt                  0
# Gross Profit              0
# Order_Year                0
# Order_Month               0
# Order_Month_Name          0
# SubcategoryName           0
# ProductCategoryKey        0
# ...

# %%
productcategories=pd.read_csv('https://raw.githubusercontent.com/KaungAlex/pandas/main/aw_Product_Categories.csv')
productcategories
# Out:
#    ProductCategoryKey CategoryName
# 0                   1        Bikes
# 1                   2   Components
# 2                   3     Clothing
# 3                   4  Accessories

# %%
productcategories.columns
# Out:
# Index(['ProductCategoryKey', 'CategoryName'], dtype='object')

# %%
productcategories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ProductCategoryKey  4 non-null      int64
#  1   CategoryName        4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %%
sales.join(productcategories.set_index('ProductCategoryKey'),on='ProductCategoryKey')
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2015-01-01 2001-09-21     SO45080         332        14657
# 1     2015-01-01 2001-12-05     SO45079         312        29255
# 2     2015-01-01 2001-10-29     SO45082         350        11455
# 3     2015-01-01 2001-11-16     SO45081         338        26782
# 4     2015-01-02 2001-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 29476 2017-12-30 2004-03-22     SO74143         477        28517
# 29477 2017-12-30 2004-03-15     SO74143         479        28517
# 29478 2017-12-30 2004-04-08     SO74143         606        28517
# 29479 2017-12-30 2004-05-15     SO74124         480        21676
# 29480 2017-12-30 2004-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity  ProductSubcategoryKey  \
# 0                 1              1              1                      2
# ...

# %%
sales=sales.join(productcategories.set_index('ProductCategoryKey'),on='ProductCategoryKey')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56046 entries, 0 to 29480
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  datetime64[ns]
#  1   StockDate              56046 non-null  datetime64[ns]
#  2   OrderNumber            56046 non-null  object
#  3   ProductKey             56046 non-null  int64
#  4   CustomerKey            56046 non-null  int64
#  5   TerritoryKey           56046 non-null  int64
#  6   OrderLineItem          56046 non-null  int64
#  7   OrderQuantity          56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductName            56046 non-null  object
#  10  ProductCost            56046 non-null  float64
#  11  ProductPrice           56046 non-null  float64
#  12  Region                 56046 non-null  object
#  13  Country                56046 non-null  object
# ...

# %%
sales[['Order_Year','CategoryName','Sales_Amt','Cost_Amt','Gross Profit']].groupby(by='CategoryName').sum().sort_values(by='Sales_Amt',ascending=False)
# Out:
#               Order_Year     Sales_Amt      Cost_Amt  Gross Profit
# CategoryName
# Bikes           28083923  2.364250e+07  1.391633e+07  9.726168e+06
# Accessories     67770632  9.066731e+05  3.369130e+05  5.697601e+05
# Clothing        17161032  3.654186e+05  2.036315e+05  1.617871e+05

# %%
sales.pivot_table(index='CategoryName',columns='Order_Year',values='Sales_Amt',aggfunc='sum').sort_values(by='CategoryName',ascending=False)
# Out:
# Order_Year            2015          2016          2017
# CategoryName
# Clothing               NaN  1.561547e+05  2.092639e+05
# Bikes         6.404934e+06  8.768707e+06  8.468855e+06
# Accessories            NaN  3.993421e+05  5.073310e+05
